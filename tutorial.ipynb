# %% [markdown]
# # COBS Tutorial: A Walkthrough
#
# |![contributions welcome](https://img.shields.io/badge/contributions-welcome-brightgreen.svg?style=flat)|[![License](http://img.shields.io/badge/license-MIT-green.svg?style=flat)](https://github.com/sustainable-computing/COBS/blob/master/LICENSE)|[![DOI](https://zenodo.org/badge/DOI/10.1145/3408308.3431119.svg)](https://doi.org/10.1145/3408308.3431119)
# |-|-|-|
#
#
# COBS is an open-source, modular building simulation platform. It facilitates the development of learning-based, occupant-centric building controls and their evaluation under different occupancy schedules and weather conditions. COBS wraps readings of building sensors in states that are defined in [EnergyPlus](https://energyplus.net/), and supports concurrent execution of control decisions on different control knobs that are available in the simulated building.
#
# To flatten the learning curve for Reinforcement Learning (RL) researchers and building scientists, COBS's interface is identical to OpenAI Gym. The diagram below shows its architecture.
#
# ![The architecture of COBS](https://cobs-platform.github.io/_images/cobs-architecture.png)

# %% [markdown]
# <a id="table-of-contents"></a>
# ## Table of Contents
# 1. [Dependencies](#installation)
# 2. [Before You Start](#model)
# 3. [Occupancy Schedules](#occupancy)
# 4. [Defining the MDP](#mdp)
#     1. [Define your state](#state)
#     2. [Wrap your action](#action)
#     3. [Define your environment](#environment)
# 5. [Example Use Case: Joint Control of Building Systems using COBS](#example)

# %% [markdown]
# <a id="installation"></a>
# ## Dependencies
#
# COBS is built on top of the python packages listed below. Make sure you install the specified versions of these packages.
#
# | Package name       | How it's used in COBS | Latest version                      | Required version |
# |:-------------------|:----------------------|:-----------------------------------:|:-----------------|
# | [Numpy][numpy web] | Main data structures  | [![numpy][numpy badge]][numpy link] | >= 1.16.0        |
# | [Eppy][eppy web]   | Built-in models       | [![eppy][eppy badge]][eppy link]    | >= 0.5.52        |
#
# [numpy web]: https://www.numpy.org/
# [numpy badge]: https://badge.fury.io/py/numpy.svg
# [numpy link]: https://badge.fury.io/py/numpy
#
# [eppy web]: https://eppy.readthedocs.io/en/latest/Main_Tutorial.html
# [eppy badge]: https://badge.fury.io/py/eppy.svg
# [eppy link]: https://badge.fury.io/py/eppy
#
# COBS requires [EnergyPlus v9.3.0](https://github.com/NREL/EnergyPlus/releases/tag/v9.3.0)
# and may not be compatible with other versions. EnergyPlus must be installed prior to using COBS.
#
# [Back to top](#table-of-contents)

# %% [markdown]
# <a id="model"></a>
# ## Preparing a Building Model
#
# Before using COBS to make your control agent interact with a simulated building, you must specify the building model and an input file for the weather data. The building model is typically an IDF file that describes the building, e.g., its floor plan, wall thickness and material, HVAC system components, their functional relationships, etc. The weather file must be in the EPW format. There are sample IDF and EPW files under the [./data](https://github.com/sustainable-computing/COBS/tree/master/cobs/data) directory.
#
# You may [create your own models](https://www.energy.gov/eere/buildings/building-energy-modeling), or borrow IDF and EPW files from
# 1. the EnergyPlus installation directory, under ``./ExampleFiles``, ``./DataSets``, and ``./WeatherData``.
# 2. the [U.S. Department of Energy website](https://www.energycodes.gov/prototype-building-models) for residential and commercial buildings.
#
# [Back to top](#table-of-contents)

# %% [markdown]
# <a id="occupancy"></a>
# ## Generating Occupancy Schedules
#
# The IDF file normally contains occupancy information for the entire duration of the simulation. In many cases, you may want to overwrite this schedule to assess the impact of dfferent occupancy schedules on the performance of your control algorithm, measured in terms of energy cost, indoor environmental quality, and so on. To enable this, COBS has a built-in module for generating occupant movement patterns within the building and creating the building-level occupancy schedule based on the IDF file that describes the building floor plan.
#
# This module allows for creating three types of schedules and has parameters that you can play with. Note that it is designed for commercial buildings so it synthesizes occupants' movements during business hours only.
#
# ### Schedules
# 1. **Fixed Schedule (Default)**: Long-term building occupants are assigned to specific private or shared offices. Thus, they spend most of their time in their office and only visit other rooms in the building for scheduled meetings and during breaks.
#
#
# 2. **CTMC-based Schedule**: Long-term building occupants visit all or a subset of building spaces in a probabilistic fashion. Specifically, once they visit a room, they will stay there for some amount of time. We assume that the time spent in room _i_ is exponentially distributed with mean _-1/q[i, i]_. After they leave this room, they move to another room _j_ in the building with probability _-q[i, j]/q[i, i]_. Room _j_ can be for example a room that is adjacent to Room _i_. For every occupant, the user has to provide the transition rate matrix _Q=[q]_ of the Continuous Time Markov Chain (CTMC) that describes how this occupant moves in the building. Our occupancy generator takes as input the transition rate matrices for all building occupants, generates traces (sample paths) of these stochastic processes, and determines the zone-level occupancy schedule by tracking how many occupants are in each room at any given point in time.
#
#
# 3. **Modified CTMC-based Schedule**: Long-term building occupants visit specific rooms during scheduled meetings and breaks (all-hands meetings and lunch time). When there is no such events, they move in the building following the CTMC-based schedule described above.
#
#
# The transition rate matrix is a square matrix that looks like this:
#
# <!-- ![image.png](attachment:image.png) -->
# ![image.png](attachment:image.png)
#
# **⚠ Remark**: Note that off-diagonal elements must be non-negative. Otherwise, the _Q_ matrix will not be valid.
#
# Each element _q[i, j]_ represents the rate of transitions from Room _i_ to Room _j_, and _n_ is the number of rooms plus two to account for the building entrance and assigned office. The diagonal elements, i.e., _q[i, i]'s_, will be replaced with values that make the row sums zero.
#
# The last row and column correspond to transition from and to the office that is assigned to the occupant. The occupancy generator randomly assigns each occupant to a room. Suppose an occupant is assined to Room _i_, the last row and column will replace the _i_th row and column in the transition rate matrix. Once this is done, we drop the last rom and column. If all elements in the last row and column are zero, then they are dropped without any replacement.
#
# It is worth mentioning that the occupancy generator also accepts one transition rate matrix for all occupants.
# In this case, the occupants will share the same transition rate matrix, but the last row and column are used to replace different rows and columns depending on the random office assignment.
#
# **⚠ Remark**: The occupancy generator creates the daily schedule for each occupant, then converts these schedules to an occupancy schedule for each zone to match the EnergyPlus input format. The obtained zone-level schedules can be written to the IDF file if the flag is set (see examples below).
#
# ### Tunable parameters for all schedules
# | Name | Description | Default value |
# |:-----|:------------|:--------------|
# |work\_start\_time|The wall-clock time denoting the start of business hour| 9:00:00 |
# |work\_end\_time|The wall-clock time denoting the end of business hour| 17:00:00 |
# |max_earliness|The parameter that controls the maximum earliness of an arrival/departure compared to work start/end time | 30 \* 60 s |
# |cut\_off\_time|The hard deadline for occupants to come to work. If the sampled arrival time is later than this, they do not come to work| 14:00:00 |
# |call\_for\_absence\_prob|The probability that a long-term occupant does not show up| 0.01 |
#
# ### Tunable parameters for scheduled events for the fixed schedule
# | Name | Description | Default value |
# |:-----|:------------|:--------------|
# |meeting\_time|The wall-clock time when the all-hands meeting begins| 16:00:00 |
# |meeting\_length\_avg|The parameter for generating all-hands meeting length (normal distribution)| 15 \* 60 s  |
# |meeting\_length\_std|See above| 60 s |
# |lunch\_break\_start|The wall-clock time when the lunch break starts| 12:00:00 |
# |lunch\_break\_end|The wall-clock time when the lunch break ends| 13:00:00 |
# |guest\_lambda|The parameter of Poisson distribution used to estimate the number of visitors per day| 3 |
# |visit\_colleague\_lambda|The parameter of Poisson distribution used to estimate the number of times occupants go to other rooms| 3 |
#
# [Back to top](#table-of-contents)

# %%
# Change the current working directory to the COBS installation directory
import os
os.chdir("D:\\Work\\COBS\\")

# %%
# A minimal example that shows how to use the CTMC-based schedule simulator
from cobs import Model
from cobs import OccupancyGenerator as OG
from tqdm import tqdm
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# E+ installation (absolute path)
# this example shows the path in Windows, but you can specify the path in Linux too
Model.set_energyplus_folder("D:\\Software\\EnergyPlus\\")

# In this example, we use sample IDF and weather files that come with COBS
# The occupancy generator requires COBS.Model to be built in advance
model = Model(idf_file_name="cobs/data/buildings/5ZoneAirCooled.idf",
              weather_file="cobs/data/weathers/USA_IL_Chicago-OHare.Intl.AP.725300_TMY3.epw")

# Let's generate the occupancy schedule with default parameters
# Note that the IDF file may already contain an occupancy schedule
# We can check the schedule of each zone (if any)
print(" ===== Before ===== ")
for zone_schedule in model.get_configuration("People"):
    print(f"Zone {zone_schedule['Zone_or_ZoneList_Name']}"
          f" is using schedule {zone_schedule['Number_of_People_Schedule_Name']}")

# Set the length of simulation to 1 day
model.set_runperiod(1, start_year=1999, specify_year=True)
# Set the number of timesteps per hour to 60, so we have minutely data
model.set_timestep(60)

occupancy = list()

# Run the experiment
state = model.reset()
with tqdm(total=model.get_total_timestep() - 1) as pbar:
    while not model.is_terminate():
        occupancy.append(state["occupancy"])
        state = model.step(None)
        pbar.update(1)

occupancy.append(state["occupancy"])
occupancy = pd.DataFrame(occupancy)
# Out:
#  ===== Before =====
# Zone SPACE1-1 is using schedule OCCUPY-1
# Zone SPACE2-1 is using schedule OCCUPY-1
# Zone SPACE3-1 is using schedule OCCUPY-1
# Zone SPACE4-1 is using schedule OCCUPY-1
# Zone SPACE5-1 is using schedule OCCUPY-1
# 100%|█████████████████████████████████████████████████████████████████████████████| 1439/1439 [00:08<00:00, 173.86it/s]

# %%
from IPython.display import HTML
occupancy.plot()
plt.show()
HTML(occupancy.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>SPACE1-1</th>
#       <th>SPACE2-1</th>
#       <th>SPACE3-1</th>
#       <th>SPACE4-1</th>
#       <th>SPACE5-1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>50</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>51</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>52</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>53</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>54</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>55</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>56</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>57</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>58</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>

# %%
# Create an OccupancyGenerator instance based on the given model
# The floor plan and room connectivity graph will be recognized
og = OG(model, num_occupant=10)

# Initialize a transition matrix for every occupant
transition_matrix_size = len(og.possible_locations)
transition_matrix = np.zeros((transition_matrix_size, transition_matrix_size)) + 1
# Assume we want occupants to mainly stay in their own office 
transition_matrix[-1, :-1] = 1 / 50000
transition_matrix[:-1, -1] = 3

og.set_transition_matrics(transition_matrix)

# The add_to_model argument will determine whether to add the existing occupancy schedule to the model
# We can also say which occupancy schedules should be overwritten
# This method returns four instances
# 1. schedule in IDF format
# 2. location of each occupant in numpy format
# 3. number of occupants in each zone in numpy format
# 4. list of all accessible locations in the building
_, _, _, _, = og.generate_daily_schedule(add_to_model=True,
                                         overwrite_dict={f"SPACE{i}-1": f"SPACE{i}-1 People 1"
                                                         for i in range(1, 6)},
                                         use_scheduled_events=False)

# Now we can check the occupancy schedule of each zone
print(" ===== After ===== ")
for zone_schedule in model.get_configuration("People"):
    print(f"Zone {zone_schedule['Zone_or_ZoneList_Name']}"
          f" is using schedule {zone_schedule['Number_of_People_Schedule_Name']}")

occupancy = list()

# Run the experiment
state = model.reset()
with tqdm(total=model.get_total_timestep() - 1) as pbar:
    while not model.is_terminate():
        occupancy.append(state["occupancy"])
        state = model.step(None)
        pbar.update(1)

occupancy.append(state["occupancy"])
occupancy = pd.DataFrame(occupancy)
# Out:
#  ===== After =====
# Zone SPACE1-1 is using schedule Generated_Schedule_Zone_SPACE1-1
# Zone SPACE2-1 is using schedule Generated_Schedule_Zone_SPACE2-1
# Zone SPACE3-1 is using schedule Generated_Schedule_Zone_SPACE3-1
# Zone SPACE4-1 is using schedule Generated_Schedule_Zone_SPACE4-1
# Zone SPACE5-1 is using schedule Generated_Schedule_Zone_SPACE5-1
# Zone PLENUM-1 is using schedule Generated_Schedule_Zone_PLENUM-1
# 100%|█████████████████████████████████████████████████████████████████████████████| 1439/1439 [00:07<00:00, 191.61it/s]

# %%
occupancy.plot()
plt.show()
HTML(occupancy.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>PLENUM-1</th>
#       <th>SPACE1-1</th>
#       <th>SPACE2-1</th>
#       <th>SPACE3-1</th>
#       <th>SPACE4-1</th>
#       <th>SPACE5-1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>50</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>51</th>
#       <t

# %% [markdown]
# <a id="mdp"></a>
# ## Defining the Markov Decision Process (MDP)
# COBS has an interface that is similar to [OpenAI Gym](http://gym.openai.com/). Thus, you can use COBS.Model just as you use a gym environment. The only difference is that in COBS you must define the state and wrap the action. This is because the list of available sensors and actuators depend on the building.
#
# [Back to top](#table-of-contents)

# %% [markdown]
# <a id="state"></a>
# ### State Definition
# The state should only contain data that is accessible from EnergyPlus during simulation. You can find what data is available during the simulation in two places:
# 1. The IDF file you use. All `Output:Variable` objects are accessible in the simulation.
# 2. The `*.rdd` file generated during the simulation. You can run the simulation for a short period of time to let EnergyPlus generate this file. Note that not all data in the `*.rdd` file is accessible in every timestep.
#
# COBS has a built-in method to list all `Output:Variable` objects in the IDF file (`COBS.Model.get_possible_state_variables()`), but it does not have any function to help you find the state variables that are available in the `*.rdd` file. The `*.rdd` file looks like this:
#
# >Program Version,EnergyPlus, Version 9.3.0-baff08990c, YMD=2021.11.04 14:33,
# >
# >Var Type (reported time step),Var Report Type,**Variable Name** [Units]
# >
# >Zone,Average,**Site Outdoor Air Drybulb Temperature** [C]
# >
# >Zone,Average,**Site Outdoor Air Dewpoint Temperature** [C]
# >
# >...
#
# This tells you the variable name. You need to go back to your IDF file and find the IDF object you are looking for.
#
# _**⚠ Remark**: Each state variable is defined by a tuple (variable name, corresponding IDF object)._
#
# -----
#
# By default, all valid `Output:Variable` objects defined in the IDF file will become part of the state. You can modify this using these methods:
# 1. `COBS.Model.select_state_variables(entry=None, index=None)`
# 2. `COBS.Model.add_state_variables(entry)`
# 3. `COBS.Model.remove_state_variables(entry)`
# 4. `COBS.Model.pop_state_variables(index)`
#
# The parameter `entry` could be one tuple or a list of tuples, and the parameter `index` can be an integer or a list of integers.
#
# [Code examples](#code-existing-state)
#
# Another way to define the state variables is to provide the `eplus_naming_dict` argument when you are defining the model `COBS.Model`, or edit `COBS.Model.eplus_naming_dict` to declare the state variables in the experiment. It is a dictionary with the following format:
# ```python
# {
#     ('Zone Thermal Comfort Fanger Model PMV', 'SPACE1-1 People 1'): "PMV Zone 1",
#     ('Lights Electric Power', 'SPACE1-1 Lights 1'): 'Lights Zone 1',
#     ...
# }
# ```
#
# Each key in this dictionary is a tuple with two elements, namely the output variable name that can be found in the `*.rdd` file, and the object name. The corresponding value is a user-defined name to describe the selected variable. This will be used as the key when you get the state values from the environment. However, you still have to make sure these variables are defined in the IDF file, otherwise you will need to add them to the model.
#
# [Code examples](#code-new-state)
#
# COBS includes some common variables in the state by default. These variables are as follows:
# 1. Current timestep (timestep)
# 2. Current datetime (time)
# 3. Zone average temperature in each zone (temperature)
# 4. The number of occupants in each zone at this time (occupancy)
# 5. Energy consumption at this time (energy)
#
# These can be used without defining `Output:Variable` objects in the IDF file.
#
# [Back to top](#table-of-contents)

# %% [markdown]
# <a id="code-existing-state"></a>
# #### Code for using the existing variables

# %%
# This is a minimal example to demonstrate how you can choose the state variables 
# that are already defined in the IDF file
from pprint import pprint
from cobs import Model

# E+ installation (absolute path)
# this example shows the path in Windows, but you can specify the path in Linux too
Model.set_energyplus_folder("D:\\Software\\EnergyPlus\\")

# We use sample IDF and weather files included in COBS
model = Model(idf_file_name="cobs/data/buildings/5ZoneAirCooled.idf",
              weather_file="cobs/data/weathers/USA_IL_Chicago-OHare.Intl.AP.725300_TMY3.epw")

# Check all available states in the IDF file
pprint(model.get_current_state_variables())
# Out:
# [('System Node Dewpoint Temperature', 'Mixed Air Node 1'),
#  ('System Node Humidity Ratio', 'Mixed Air Node 1'),
#  ('System Node Humidity Ratio', 'OA Heating Coil 1 Air Outlet Node'),
#  ('System Node Humidity Ratio', 'OA Mixing Box 1 Inlet Node'),
#  ('System Node Humidity Ratio', 'VAV Sys 1 Outlet Node'),
#  ('System Node Mass Flow Rate', 'Main Cooling Coil 1 Water Inlet Node'),
#  ('System Node Mass Flow Rate', 'Main Heating Coil 1 Water Inlet Node'),
#  ('System Node Mass Flow Rate', 'OA Cooling Coil 1 Water Inlet Node'),
#  ('System Node Mass Flow Rate', 'OA Heating Coil 1 Air Outlet Node'),
#  ('System Node Mass Flow Rate', 'OA Heating Coil 1 Water Inlet Node'),
#  ('System Node Mass Flow Rate', 'OA Mixing Box 1 Inlet Node'),
#  ('System Node Mass Flow Rate', 'VAV Sys 1 Outlet Node'),
#  ('System Node Setpoint Temperature', 'OA Heating Coil 1 Air Outlet Node'),
#  ('System Node Setpoint Temperature', 'OA Mixing Box 1 Inlet Node'),
#  ('System Node Setpoint Temperature', 'VAV Sys 1 Outlet Node'),
#  ('System Node Temperature', 'Mixed Air Node 1'),
#  ('System Node Temperature', 'OA Cooling Coil 1 Water Inlet Node'),
#  ('System Node Temperature', 'OA Heating Coil 1 Air Outlet Node'),
#  ('System Node Temperature', 'OA Heating Coil 1 Water Inlet Node'),
#  ('System Node Temperature', 'OA Mixing Box 1 Inlet Node'),
#  ('System Node Temperature', 'VAV Sys 1 Outlet Node')]

# %%
# Let's just select three of them as our state variables
model.select_state_variables(index=[0, 1, 5])
pprint(model.get_current_state_variables())
# Out:
# [('System Node Dewpoint Temperature', 'Mixed Air Node 1'),
#  ('System Node Humidity Ratio', 'Mixed Air Node 1'),
#  ('System Node Mass Flow Rate', 'Main Cooling Coil 1 Water Inlet Node')]

# %%
# You can use the tuple to add/delete state variables
model.add_state_variables(('System Node Temperature', 'Mixed Air Node 1'))
pprint(model.get_current_state_variables())
# Out:
# [('System Node Dewpoint Temperature', 'Mixed Air Node 1'),
#  ('System Node Humidity Ratio', 'Mixed Air Node 1'),
#  ('System Node Mass Flow Rate', 'Main Cooling Coil 1 Water Inlet Node'),
#  ('System Node Temperature', 'Mixed Air Node 1')]

# %%
# Run the experiment with the selected state variables
# To reduce the running time, we just simulate for one day
model.set_runperiod(1)
# Using 30-minute timesteps
model.set_timestep(2)

# Run the experiment
state = model.reset()
while not model.is_terminate():
    pprint(state)
    state = model.step(None)

pprint(state)
print("Done")
# Out:
# {'System Node Dewpoint Temperature_Mixed Air Node 1': 0.0,
#  'System Node Humidity Ratio_Mixed Air Node 1': 0.001866002022339802,
#  'System Node Mass Flow Rate_Main Cooling Coil 1 Water Inlet Node': 0.0,
#  'System Node Temperature_Mixed Air Node 1': 15.435362078079983,
#  'energy': 0.0,
#  'occupancy': {'SPACE1-1': 0.0,
#                'SPACE2-1': 0.0,
#                'SPACE3-1': 0.0,
#                'SPACE4-1': 0.0,
#                'SPACE5-1': 0.0},
#  'temperature': {'PLENUM-1': 15.689583476021653,
#                  'SPACE1-1': 17.310843051827728,
#                  'SPACE2-1': 17.341444224351044,
#                  'SPACE3-1': 17.313006562227415,
#                  'SPACE4-1': 17.31802688065112,
#                  'SPACE5-1': 19.00849530542632},
#  'terminate': False,
#  'time': datetime.datetime(1986, 1, 1, 0, 30),
#  'timestep': 0}
# {'System Node Dewpoint Temperature_Mixed Air Node 1': -8.504943233535409,
#  'System Node Humidity Ratio_Mixed Air Node 1': 0.0018641129328823538,
#  'System Node Mass Flow Rate_Main Cooling Coil 1 Water Inlet Node': 0.0,
#  'System Node Temperature_Mixed Air Node 1': 15.3068388560961,
#  'energy': 1488026.764111471,
#  'occupancy': {'SPACE1-1': 0.0,
#                'SPACE2-1': 0.0,
#                'SPACE3-1': 0.0,
#                'SPACE4-1': 0.0,
#                'SPACE5-1': 0.0},
#  'temperature': {'PLENUM-1': 15.645406516931908,
#                  'SPACE1-1': 17.145569987037216,
#                  'SPACE2-1': 17.20654593612832,
#                  'SPACE3-1': 17.156753677115617,
#                  'SPACE4-1': 17.184311186491012,
#                  'SPACE5-1': 18.96406377886958},
#  'terminate': False,
#  'time': datetime.datetime(1986, 1, 1, 1, 0),
#  'timestep': 1}
# {'System Node Dewpoint Temperature_Mixed Air Node 1': -8.473300168138936,
#  'System Node Humidity Ratio_Mixed Air Node 1': 0.0018646015164662376,
#  'System Node Mass Flow Rate_Main Cooling Coil 1 Water Inlet Node': 0.0,
#  'System Node Temperature_Mixed Air Node 1': 15.17514908740688,
#  'energy': 1451207.6893938356,
#  'occupancy': {'SPACE1-1': 0.0,
#                'SPACE2-1': 0.0,
#                'SPACE3-1': 0.0,
#                'SPACE4-1': 0.0,
#                'SPACE5-1': 0.0},
#  'temperature': {'PLENUM-1': 15.57433514865127,
#                  'SPACE1-1': 16.891395680725825,
#                  'SPACE2-1': 17.003301272514662,
#                  'SPACE3-1': 16.91474797479312,
#                  'SPACE4-1': 16.982645916560806,
#                  'SPACE5-1': 18.900328514413477},
#  'terminate': False,
#  'time': datetime.datetime(1986, 1, 1, 1, 30),
#  'timestep': 2}
# {'System Node Dewpoint Temperature_Mixed Air Node 1': -8.456966179291676,
#  'System Node Humidity Ratio_Mixed Air Node 1': 0.0018663431837425504,
#  'System Node Mass Flow Rate_Main Cooling Coil 1 Water Inlet Node': 0.0,
#  'System Node Temperature_Mixed Air Node 1': 15.109482815874143,
#  'energy': 1400709.5095847321,
#  'occupancy': {'SPACE1-1': 0.0,
#                'SPACE2-1': 0.0,
#                'SPACE3-1': 0.0,
#                'SPACE4-1': 0.0,
#                'SPACE5-1': 0.0},
#  'temperature': {'PLENUM-1': 15.457950400261227,
#                  'SPACE1-1': 16.73187555808426,
#                  'SPACE2-1': 16.868340844850767,
#                  'SPACE3-1': 16.761407080283988,
#                  'SPACE4-1': 16.849355260222584,
#                  'SPACE5-1': 18.851970121374205},
#  'terminate': False,
#  'time': datetime.datetime(1986, 1, 1, 2, 0),
#  'timestep': 3}
# {'System Node Dewpoint Temperature_Mixed Air Node 1': -8.520840833902778,
#  'System Node Humidity Ratio_Mixed Air Node 1': 0.0018549447489193637,
#  'System Node Mass Flow Rate_Main Cooling Coil 1 Water Inlet Node': 0.0,
#  'System Node Temperature_Mixed Air Node 1': 14.999257394246529,
#  'energy': 1588548.6552345178,
#  'occupancy': {'SPACE1-1': 0.0,
#                'SPACE2-1': 0.0,
#                'SPACE3-1': 0.0,
#                'SPACE4-1': 0.0,
#                'SPACE5-1': 0.0},
#  'temperature': {'PLENUM-1': 15.30732572854248,
#                  'SPACE1-1': 16.7020097265744,
#                  'SPACE2-1': 16.764802314874352,
#                  'SPACE3-1': 16.702221233829427,
#                  'SPACE4-1': 16.746736223094054,
#                  'SPACE5-1': 18.80927248932609},
#  'terminate': False,
#  'time': datetime.datetime(1986, 1, 1, 2, 30),
#  'timestep': 4}
# {'System Node Dewpoint Temperature_Mixed Air Node 1': -8.637225387453709,
#  'System Node Humidity Ratio_Mixed Air Node 1': 0.0018369511659984878,
#  'System Node Mass Flow Rate_Main Cooling Coil 1 Water Inlet Node': 0.0,
#  'System Node Temperature_Mixed Air Node 1': 14.856205052179263,
#  'energy': 1871494.6422450615,
#  'occupancy': {'SPACE1-1': 0.0,
#                'SPACE2-1': 0.0,
#                'SPACE3-1': 0.0,
#                'SPACE4-1': 0.0,
#                'SPACE5-1': 0.0},
#  'temperature': {'PLENUM-1': 15.143708354667572,
#                  'SPACE1-1': 16.699463120951858,
#                  'SPACE2-1': 16.706374224727934,
#                  'SPACE3-1': 16.699988899986366,
#                  'SPACE4-1': 16.70479929758573,
#                  'SPACE5-1': 18.78175834205966},
#  'terminate': False,
#  'time': datetime.datetime(1986, 1, 1, 3, 0),
#  'timestep': 5}
# {'System Node Dewpoint Temperature_Mixed Air Node 1': -8.747244645490147,
#  'System Node Humidity Ratio_Mixed Air Node 1': 0.0018201379931266498,
#  'System Node Mass Flow Rate_Main Cooling Coil 1 Water Inlet Node': 0.0,
#  'System Node Temperature_Mixed Air Node 1': 14.700381161158813,
#  'energy': 2066252.8023732137,
#  'occupancy': {'SPACE1-1': 0.0,
#                'SPACE2-1': 0.0,
#                'SPACE3-1': 0.0,
#                'SPACE4-1': 0.0,
#                'SPACE5-1': 0.0},
#  'temperature': {'PLENUM-1': 14.98355199203369,
#                  'SPACE1-1': 16.699992508990434,
#                  'SPACE2-1': 16.699901686594103,
#                  'SPACE3-1': 16.700554894549338,
#                  'SPACE4-1': 16.700356395304013,
#                  'SPACE5-1': 18.764513224914335},
#  'terminate': False,
#  'time': datetime.datetime(1986, 1, 1, 3, 30),
#  'timestep': 6}
# {'System Node Dewpoint Temperature_Mixed Air Node 1': -8.833164648448356,
#  'System Node Humidity Ratio_Mixed Air Node 1': 0.0018063939268912323,
#  'System Node Mass Flow Rate_Main Cooling Coil 1 Water Inlet Node': 0.0,
#  'System Node Temperature_Mixed Air Node 1': 14.54291910639199,
#  'energy': 2477016.655193771,
#  'occupancy': {'SPACE1-1': 0.0,
#                'SPACE2-1': 0.0,
#                'SPACE3-1': 0.0,
#                'SPACE4-1': 0.0,
#                'SPACE5-1': 0.0},
#  'temperature': {'PLENUM-1': 14.83429818314545,
#                  'SPACE1-1': 16.70033654949315,
#                  'SPACE2-1': 16.700592790272403,
#                  'SPACE3-1': 16.699542192895315,
#                  'SPACE4-1': 16.700905208283185,
#                  'SPACE5-1': 18.728276425650282},
#  'terminate': False,
#  'time': datetime.datetime(1986, 1, 1, 4, 0),
#  'timestep': 7}
# {'System Node Dewpoint Temperature_Mixed Air Node 1': -8.905658946519686,
#  'System Node Humidity Ratio_Mixed Air Node 1': 0.0017948715823063667,
#  'System Node Mass Flow Rate_Main Cooling Coil 1 Water Inlet Node': 0.0,
#  'System Node Temperature_Mixed Air Node 1': 14.396177353786332,
#  'energy': 2825068.7898603026,
#  'occupancy': {'SPACE1-1': 0.0,
#                'SPACE2-1': 0.0,
#                'SPACE3-1': 0.0,
#                'SPACE4-1': 0.0,
#                'SPACE5-1': 0.0},
#  'temperature': {'PLENUM-1': 14.697595583379375,
#                  'SPACE1-1': 16.699882257508825,
#                  'SPACE2-1': 16.700852980422255,
#                  'SPACE3-1': 16.6996192420893,
#                  'SPACE4-1': 16.699362091398378,
#                  'SPACE5-1': 18.682336768607364},
#  'terminate': False,
#  'time': datetime.datetime(1986, 1, 1, 4, 30),
#  'timestep': 8}
# {'System Node Dewpoint Temperature_Mixed Air Node 1': -8.976907261468693,
#  'System Node Humidity Ratio_Mixed Air Node 1': 0.0017836129673672548,
#  'System Node Mass Flow Rate_Main Cooling Coil 1 Water Inlet Node': 0.0,
#  'System Node Temperature_Mixed Air Node 1': 14.265979108343519,
#  'energy': 2985984.377636442,
#  'occupancy': {'SPACE1-1': 0.0,
#                'SPACE2-1': 0.0,
#                'SPACE3-1': 0.0,
#                'SPACE4-1': 0.0,
#                'SPACE5-1': 0.0},
#  'temperature': {'PLENUM-1': 14.573563199349566,
#                  'SPACE1-1': 16.69906090946388,
#                  'SPACE2-1': 16.699505791906493,
#                  'SPACE3-1': 16.70018331888356,
#                  'SPACE4-1': 16.700124388946104,
#                  'SPACE5-1': 18.648624920631867},
#  'terminate': False,
#  'time': datetime.datetime(1986, 1, 1, 5, 0),
#  'timestep': 9}
# {'System Node Dewpoint Temperature_Mixed Air Node 1': -9.056471663675788,
#  'System Node Humidity Ratio_Mixed Air Node 1': 0.001771116710903472,
#  'System Node Mass Flow Rate_Main Cooling Coil 1 Water Inlet Node': 0.0,
#  'System Node Temperature_Mixed Air Node 1': 14.148236497491192,
#  'energy': 3108121.9077109247,
#  'occupancy': {'SPACE1-1': 0.0,
#                'SPACE2-1': 0.0,
#                'SPACE3-1': 0.0,
#                'SPACE4-1': 0.0,
#                'SPACE5-1': 0.0},
#  'temperature': {'PLENUM-1': 14.462687034403563,
#                  'SPACE1-1': 16.69937908002783,
#                  'SPACE2-1': 16.699608310553987,
#                  'SPACE3-1': 16.700768303457433,
#                  'SPACE4-1': 16.701625441336887,
#                  'SPACE5-1': 18.62380300581114},
#  'terminate': False,
#  'time': datetime.datetime(1986, 1, 1, 5, 30),
#  'timestep': 10}
# {'System Node Dewpoint Temperature_Mixed Air Node 1': -9.141366326795788,
#  'System Node Humidity Ratio_Mixed Air Node 1': 0.0017578718560996168,
#  'System Node Mass Flow Rate_Main Cooling Coil 1 Water Inlet Node': 0.0,
#  'System Node Temperature_Mixed Air Node 1': 14.03922332837138,
#  'energy': 3235686.9042356154,
#  'occupancy': {'SPACE1-1': 0.0,
#                'SPACE2-1': 0.0,
#                'SPACE3-1': 0.0,
#                'SPACE4-1': 0.0,
#                'SPACE5-1': 0.0},
#  'temperature': {'PLENUM-1': 14.36498224545405,
#                  'SPACE1-1': 16.699440837650734,
#                  'SPACE2-1': 16.699010591513964,
#                  'SPACE3-1': 16.70081525748529,
#                  'SPACE4-1': 16.699127971217823,
#                  'SPACE5-1': 18.601938133853633},
#  'terminate': False,
#  'time': datetime.datetime(1986, 1, 1, 6, 0),
#  'timestep': 11}
# {'System Node Dewpoint Temperature_Mixed Air Node 1': -9.221627398319942,
#  'System Node Humidity Ratio_Mixed Air Node 1': 0.001745433429033889,
#  'System Node Mass Flow Rate_Main Cooling Coil 1 Water Inlet Node': 0.0,
#  'System Node Temperature_Mixed Air Node 1': 13.943159702146115,
#  'energy': 3353090.2014965247,
#  'occupancy': {'SPACE1-1': 0.0,
#                'SPACE2-1': 0.0,
#                'SPACE3-1': 0.0,
#                'SPACE4-1': 0.0,
#                'SPACE5-1': 0.0},
#  'temperature': {'PLENUM-1': 14.279293871517687,
#                  'SPACE1-1': 16.700543620730194,
#                  'SPACE2-1': 16.699462648131625,
#                  'SPACE3-1': 16.699309304247258,
#                  'SPACE4-1': 16.701188456683603,
#                  'SPACE5-1': 18.58220300115542},
#  'terminate': False,
#  'time': datetime.datetime(1986, 1, 1, 6, 30),
#  'timestep': 12}
# {'System Node Dewpoint Temperature_Mixed Air Node 1': -9.293874575459373,
#  'System Node Humidity Ratio_Mixed Air Node 1': 0.0017343059981464745,
#  'System Node Mass Flow Rate_Main Cooling Coil 1 Water Inlet Node': 0.0,
#  'System Node Temperature_Mixed Air Node 1': 13.858886547125996,
#  'energy': 3539140.8953368952,
#  'occupancy': {'SPACE1-1': 0.0,
#                'SPACE2-1': 0.0,
#                'SPACE3-1': 0.0,
#                'SPACE4-1': 0.0,
#                'SPACE5-1': 0.0},
#  'temperature': {'PLENUM-1': 14.204613269687872,
#                  'SPACE1-1': 16.700791118485743,
#                  'SPACE2-1': 16.700297541502632,
#                  'SPACE3-1': 16.700880220106992,
#                  'SPACE4-1': 16.700649724591432,
#                  'SPACE5-1': 18.55331620785031},
#  'terminate': False,
#  'time': datetime.datetime(1986, 1, 1, 7, 0),
#  'timestep': 13}
# {'System Node Dewpoint Temperature_Mixed Air Node 1': -9.364894782167134,
#  'System Node Humidity Ratio_Mixed Air Node 1': 0.0017234309773274598,
#  'System Node Mass Flow Rate_Main Cooling Coil 1 Water Inlet Node': 0.0,
#  'System Node Temperature_Mixed Air Node 1': 13.785435557875234,
#  'energy': 3698670.1128643136,
#  'occupancy': {'SPACE1-1': 0.0,
#                'SPACE2-1': 0.0,
#                'SPACE3-1': 0.0,
#                'SPACE4-1': 0.0,
#                'SPACE5-1': 0.0},
#  'temperature': {'PLENUM-1': 14.13818766980622,
#                  'SPACE1-1': 16.700560905751193,
#                  'SPACE2-1': 16.69907099238415,
#                  'SPACE3-1': 16.699129357692804,
#                  'SPACE4-1': 16.698600777254036,
#                  'SPACE5-1': 18.519632850738642},
#  'terminate': False,
#  'time': datetime.datetime(1986, 1, 1, 7, 30),
#  'timestep': 14}
# {'System Node Dewpoint Temperature_Mixed Air Node 1': -9.436604988378358,
#  'System Node Humidity Ratio_Mixed Air Node 1': 0.0017125137363500173,
#  'System Node Mass Flow Rate_Main Cooling Coil 1 Water Inlet Node': 0.0,
#  'System Node Temperature_Mixed Air Node 1': 13.725169352864995,
#  'energy': 3420400.0279873405,
#  'occupancy': {'SPACE1-1': 0.0,
#                'SPACE2-1': 0.0,
#                'SPACE3-1': 0.0,
#                'SPACE4-1': 0.0,
#                'SPACE5-1': 0.0},
#  'temperature': {'PLENUM-1': 14.081265474872856,
#                  'SPACE1-1': 16.70011716705968,
#                  'SPACE2-1': 16.700128935528877,
#                  'SPACE3-1': 16.69960337064683,
#                  'SPACE4-1': 16.69931112027956,
#                  'SPACE5-1': 18.510634961913663},
#  'terminate': False,
#  'time': datetime.datetime(1986, 1, 1, 8, 0),
#  'timestep': 15}
# {'System Node Dewpoint Temperature_Mixed Air Node 1': -9.53106104795273,
#  'System Node Humidity Ratio_Mixed Air Node 1': 0.0016982304337008571,
#  'System Node Mass Flow Rate_Main Cooling Coil 1 Water Inlet Node': 0.0,
#  'System Node Temperature_Mixed Air Node 1': 13.645531577817344,
#  'energy': 2917878.8322876953,
#  'occupancy': {'SPACE1-1': 0.0,
#                'SPACE2-1': 0.0,
#                'SPACE3-1': 0.0,
#                'SPACE4-1': 0.0,
#                'SPACE5-1': 0.0},
#  'temperature': {'PLENUM-1': 14.04745459471312,
#                  'SPACE1-1': 16.700155015697632,
#                  'SPACE2-1': 17.36565799549328,
#                  'SPACE3-1': 16.69999400930726,
#                  'SPACE4-1': 16.70057336144141,
#                  'SPACE5-1': 18.523735419906725},
#  'terminate': False,
#  'time': datetime.datetime(1986, 1, 1, 8, 30),
#  'timestep': 16}
# {'System Node Dewpoint Temperature_Mixed Air Node 1': -9.60068128385352,
#  'System Node Humidity Ratio_Mixed Air Node 1': 0.0016877726924983763,
#  'System Node Mass Flow Rate_Main Cooling Coil 1 Water Inlet Node': 0.0,
#  'System Node Temperature_Mixed Air Node 1': 13.657289523333807,
#  'energy': 2414327.1844725,
#  'occupancy': {'SPACE1-1': 0.0,
#                'SPACE2-1': 0.0,
#                'SPACE3-1': 0.0,
#                'SPACE4-1': 0.0,
#                'SPACE5-1': 0.0},
#  'temperature': {'PLENUM-1': 14.062947559680456,
#                  'SPACE1-1': 16.69991720568069,
#                  'SPACE2-1': 18.320391267056028,
#                  'SPACE3-1': 16.69988934811872,
#                  'SPACE4-1': 16.699973507553544,
#                  'SPACE5-1': 18.52434575891274},
#  'terminate': False,
#  'time': datetime.datetime(1986, 1, 1, 9, 0),
#  'timestep': 17}
# {'System Node Dewpoint Temperature_Mixed Air Node 1': -9.676059457967602,
#  'System Node Humidity Ratio_Mixed Air Node 1': 0.00167651660189856,
#  'System Node Mass Flow Rate_Main Cooling Coil 1 Water Inlet Node': 0.0,
#  'System Node Temperature_Mixed Air Node 1': 13.728622327477073,
#  'energy': 2364414.0453609433,
#  'occupancy': {'SPACE1-1': 0.0,
#                'SPACE2-1': 0.0,
#                'SPACE3-1': 0.0,
#                'SPACE4-1': 0.0,
#                'SPACE5-1': 0.0},
#  'temperature': {'PLENUM-1': 14.123916863579284,
#                  'SPACE1-1': 16.889914901811643,
#                  'SPACE2-1': 19.196571320371486,
#                  'SPACE3-1': 16.700507320089113,
#                  'SPACE4-1': 16.70169471999636,
#                  'SPACE5-1': 18.533014490920074},
#  'terminate': False,
#  'time': datetime.datetime(1986, 1, 1, 9, 30),
#  'timestep': 18}
# {'System Node Dewpoint Temperature_Mixed Air Node 1': -9.754362459367366,
#  'System Node Humidity Ratio_Mixed Air Node 1': 0.0016648966261318865,
#  'System Node Mass Flow Rate_Main Cooling Coil 1 Water Inlet Node': 0.0,
#  'System Node Temperature_Mixed Air Node 1': 13.856782545245153,
#  'energy': 2432850.3668109593,
#  'occupancy': {'SPACE1-1': 0.0,
#                'SPACE2-1': 0.0,
#                'SPACE3-1': 0.0,
#                'SPACE4-1': 0.0,
#                'SPACE5-1': 0.0},
#  'temperature': {'PLENUM-1': 14.23441914802408,
#                  'SPACE1-1': 17.195618384354802,
#                  'SPACE2-1': 19.977334573041603,
#                  'SPACE3-1': 16.75560637309427,
#                  'SPACE4-1': 16.75994960847573,
#                  'SPACE5-1': 18.498874533308626},
#  'terminate': False,
#  'time': datetime.datetime(1986, 1, 1, 10, 0),
#  'timestep': 19}
# {'System Node Dewpoint Temperature_Mixed Air Node 1': -9.846119180105722,
#  'System Node Humidity Ratio_Mixed Air Node 1': 0.00165137419629978,
#  'System Node Mass Flow Rate_Main Cooling Coil 1 Water Inlet Node': 0.0,
#  'System Node Temperature_Mixed Air Node 1': 14.030698075131491,
#  'energy': 2470604.2449272107,
#  'occupancy': {'SPACE1-1': 0.0,
#                'SPACE2-1': 0.0,
#                'SPACE3-1': 0.0,
#                'SPACE4-1': 0.0,
#                'SPACE5-1': 0.0},
#  'temperature': {'PLENUM-1': 14.389871665462088,
#                  'SPACE1-1': 17.570862778862903,
#                  'SPACE2-1': 20.53622283510224,
#                  'SPACE3-1': 16.830070589863183,
#                  'SPACE4-1': 16.828225570890122,
#                  'SPACE5-1': 18.467512253528266},
#  'terminate': False,
#  'time': datetime.datetime(1986, 1, 1, 10, 30),
#  'timestep': 20}
# {'System Node Dewpoint Temperature_Mixed Air Node 1': -9.857530964053305,
#  'System Node Humidity Ratio_Mixed Air Node 1': 0.0016505310722605448,
#  'System Node Mass Flow Rate_Main Cooling Coil 1 Water Inlet Node': 0.0,
#  'System Node Temperature_Mixed Air Node 1': 14.19499354192867,
#  'energy': 2446690.6969813188,
#  'occupancy': {'SPACE1-1': 0.0,
#                'SPACE2-1': 0.0,
#                'SPACE3-1': 0.0,
#                'SPACE4-1': 0.0,
#                'SPACE5-1': 0.0},
#  'temperature': {'PLENUM-1': 14.600355095127794,
#                  'SPACE1-1': 18.09457786885224,
#                  'SPACE2-1': 20.990742124842694,
#                  'SPACE3-1': 16.965849988375176,
#                  'SPACE4-1': 16.952120689870007,
#                  'SPACE5-1': 18.506121785637106},
#  'terminate': False,
#  'time': datetime.datetime(1986, 1, 1, 11, 0),
#  'timestep': 21}
# {'System Node Dewpoint Temperature_Mixed Air Node 1': -9.92093872607642,
#  'System Node Humidity Ratio_Mixed Air Node 1': 0.0016420770802049285,
#  'System Node Mass Flow Rate_Main Cooling Coil 1 Water Inlet Node': 0.0,
#  'System Node Temperature_Mixed Air Node 1': 14.453845454514981,
#  'energy': 2445772.4238653043,
#  'occupancy': {'SPACE1-1': 0.0,
#                'SPACE2-1': 0.0,
#                'SPACE3-1': 0.0,
#                'SPACE4-1': 0.0,
#                'SPACE5-1': 0.0},
#  'temperature': {'PLENUM-1': 14.846234498071821,
#                  'SPACE1-1': 18.57880560319986,
#                  'SPACE2-1': 21.09336458111357,
#                  'SPACE3-1': 17.15125099558262,
#                  'SPACE4-1': 17.121830252535293,
#                  'SPACE5-1': 18.57094830575061},
#  'terminate': False,
#  'time': datetime.datetime(1986, 1, 1, 11, 30),
#  'timestep': 22}
# {'System Node Dewpoint Temperature_Mixed Air Node 1': -9.94653060214486,
#  'System Node Humidity Ratio_Mixed Air Node 1': 0.0016391692737187556,
#  'System Node Mass Flow Rate_Main Cooling Coil 1 Water Inlet Node': 0.0,
#  'System Node Temperature_Mixed Air Node 1': 14.739990007255939,
#  'energy': 2396332.2705722656,
#  'occupancy': {'SPACE1-1': 0.0,
#                'SPACE2-1': 0.0,
#                'SPACE3-1': 0.0,
#                'SPACE4-1': 0.0,
#                'SPACE5-1': 0.0},
#  'temperature': {'PLENUM-1': 15.125362426626019,
#                  'SPACE1-1': 19.024497203564163,
#                  'SPACE2-1': 20.991105938691252,
#                  'SPACE3-1': 17.335897645083357,
#                  'SPACE4-1': 17.30038970110282,
#                  'SPACE5-1': 18.64790887116865},
#  'terminate': False,
#  'time': datetime.datetime(1986, 1, 1, 12, 0),
#  'timestep': 23}
# {'System Node Dewpoint Temperature_Mixed Air Node 1': -9.935235150219802,
#  'System Node Humidity Ratio_Mixed Air Node 1': 0.0016416457851217978,
#  'System Node Mass Flow Rate_Main Cooling Coil 1 Water Inlet Node': 0.0,
#  'System Node Temperature_Mixed Air Node 1': 15.020801581985118,
#  'energy': 2301988.3183821435,
#  'occupancy': {'SPACE1-1': 0.0,
#                'SPACE2-1': 0.0,
#                'SPACE3-1': 0.0,
#                'SPACE4-1': 0.0,
#                'SPACE5-1': 0.0},
#  'temperature': {'PLENUM-1': 15.387006533742982,
#                  'SPACE1-1': 19.19058290798553,
#                  'SPACE2-1': 20.56969527411609,
#                  'SPACE3-1': 17.48777344989051,
#                  'SPACE4-1': 17.44534739959001,
#                  'SPACE5-1': 18.727736669234964},
#  'terminate': False,
#  'time': datetime.datetime(1986, 1, 1, 12, 30),
#  'timestep': 24}
# {'System Node Dewpoint Temperature_Mixed Air Node 1': -9.892867418025036,
#  'System Node Humidity Ratio_Mixed Air Node 1': 0.0016486769076987755,
#  'System Node Mass Flow Rate_Main Cooling Coil 1 Water Inlet Node': 0.0,
#  'System Node Temperature_Mixed Air Node 1': 15.267923013007634,
#  'energy': 2159321.6531255967,
#  'occupancy': {'SPACE1-1': 0.0,
#                'SPACE2-1': 0.0,
#                'SPACE3-1': 0.0,
#                'SPACE4-1': 0.0,
#                'SPACE5-1': 0.0},
#  'temperature': {'PLENUM-1': 15.61999714983071,
#                  'SPACE1-1': 19.134282942772455,
#                  'SPACE2-1': 20.089319759586974,
#                  'SPACE3-1': 17.628365689720603,
#                  'SPACE4-1': 17.59508457143832,
#                  'SPACE5-1': 18.812631271008954},
#  'terminate': False,
#  'time': datetime.datetime(1986, 1, 1, 13, 0),
#  'timestep': 25}
# {'System Node Dewpoint Temperature_Mixed Air Node 1': -9.82302151234528,
#  'System Node Humidity Ratio_Mixed Air Node 1': 0.00165978630490398,
#  'System Node Mass Flow Rate_Main Cooling Coil 1 Water Inlet Node': 0.0,
#  'System Node Temperature_Mixed Air Node 1': 15.483088998319454,
#  'energy': 2013833.6566177492,
#  'occupancy': {'SPACE1-1': 0.0,
#                'SPACE2-1': 0.0,
#                'SPACE3-1': 0.0,
#                'SPACE4-1': 0.0,
#                'SPACE5-1': 0.0},
#  'temperature': {'PLENUM-1': 15.825453668253706,
#                  'SPACE1-1': 19.129842570540017,
#                  'SPACE2-1': 19.709614521945003,
#                  'SPACE3-1': 17.757468178826098,
#                  'SPACE4-1': 17.73689348872675,
#                  'SPACE5-1': 18.89247534581147},
#  'terminate': False,
#  'time': datetime.datetime(1986, 1, 1, 13, 30),
#  'timestep': 26}
# {'System Node Dewpoint Temperature_Mixed Air Node 1': -9.733505707230485,
#  'System Node Humidity Ratio_Mixed Air Node 1': 0.001673042394573015,
#  'System Node Mass Flow Rate_Main Cooling Coil 1 Water Inlet Node': 0.0,
#  'System Node Temperature_Mixed Air Node 1': 15.665670641525551,
#  'energy': 1897734.6492030844,
#  'occupancy': {'SPACE1-1': 0.0,
#                'SPACE2-1': 0.0,
#                'SPACE3-1': 0.0,
#                'SPACE4-1': 0.0,
#                'SPACE5-1': 0.0},
#  'temperature': {'PLENUM-1': 15.994908018343319,
#                  'SPACE1-1': 19.05145188569646,
#                  'SPACE2-1': 19.38960990761049,
#                  'SPACE3-1': 17.87621780818514,
#                  'SPACE4-1': 17.864930132656294,
#                  'SPACE5-1': 18.97579179754356},
#  'terminate': False,
#  'time': datetime.datetime(1986, 1, 1, 14, 0),
#  'timestep': 27}
# {'System Node Dewpoint Temperature_Mixed Air Node 1': -9.677560241422624,
#  'System Node Humidity Ratio_Mixed Air Node 1': 0.0016813763185496485,
#  'System Node Mass Flow Rate_Main Cooling Coil 1 Water Inlet Node': 0.0,
#  'System Node Temperature_Mixed Air Node 1': 15.705487174031214,
#  'energy': 1803302.5265628286,
#  'occupancy': {'SPACE1-1': 0.0,
#                'SPACE2-1': 0.0,
#                'SPACE3-1': 0.0,
#                'SPACE4-1': 0.0,
#                'SPACE5-1': 0.0},
#  'temperature': {'PLENUM-1': 16.120770506086647,
#                  'SPACE1-1': 19.023533293557595,
#                  'SPACE2-1': 19.147076813651793,
#                  'SPACE3-1': 17.936036851916565,
#                  'SPACE4-1': 17.929772745566673,
#                  'SPACE5-1': 19.038010940142154},
#  'terminate': False,
#  'time': datetime.datetime(1986, 1, 1, 14, 30),
#  'timestep': 28}
# {'System Node Dewpoint Temperature_Mixed Air Node 1': -9.608627362671808,
#  'System Node Humidity Ratio_Mixed Air Node 1': 0.001691697269111822,
#  'System Node Mass Flow Rate_Main Cooling Coil 1 Water Inlet Node': 0.0,
#  'System Node Temperature_Mixed Air Node 1': 15.829195937856872,
#  'energy': 1721693.029526263,
#  'occupancy': {'SPACE1-1': 0.0,
#                'SPACE2-1': 0.0,
#                'SPACE3-1': 0.0,
#                'SPACE4-1': 0.0,
#                'SPACE5-1': 0.0},
#  'temperature': {'PLENUM-1': 16.232134045631653,
#                  'SPACE1-1': 19.04952693042186,
#                  'SPACE2-1': 18.907445813318844,
#                  'SPACE3-1': 17.96271973327206,
#                  'SPACE4-1': 17.989134949868127,
#                  'SPACE5-1': 19.099915871030834},
#  'terminate': False,
#  'time': datetime.datetime(1986, 1, 1, 15, 0),
#  'timestep': 29}
# {'System Node Dewpoint Temperature_Mixed Air Node 1': -9.52593144878366,
#  'System Node Humidity Ratio_Mixed Air Node 1': 0.0017041555212521024,
#  'System Node Mass Flow Rate_Main Cooling Coil 1 Water Inlet Node': 0.0,
#  'System Node Temperature_Mixed Air Node 1': 15.93865208150203,
#  'energy': 1659016.7541046215,
#  'occupancy': {'SPACE1-1': 0.0,
#                'SPACE2-1': 0.0,
#                'SPACE3-1': 0.0,
#                'SPACE4-1': 0.0,
#                'SPACE5-1': 0.0},
#  'temperature': {'PLENUM-1': 16.31926656949557,
#                  'SPACE1-1': 19.002127876101117,
#                  'SPACE2-1': 18.714391175491123,
#                  'SPACE3-1': 17.958211875331113,
#                  'SPACE4-1': 18.033748655504898,
#                  'SPACE5-1': 19.154422016814266},
#  'terminate': False,
#  'time': datetime.datetime(1986, 1, 1, 15, 30),
#  'timestep': 30}
# {'System Node Dewpoint Temperature_Mixed Air Node 1': -9.440151913002572,
#  'System Node Humidity Ratio_Mixed Air Node 1': 0.001717167086740814,
#  'System Node Mass Flow Rate_Main Cooling Coil 1 Water Inlet Node': 0.0,
#  'System Node Temperature_Mixed Air Node 1': 16.024268401821026,
#  'energy': 1604963.7658356319,
#  'occupancy': {'SPACE1-1': 0.0,
#                'SPACE2-1': 0.0,
#                'SPACE3-1': 0.0,
#                'SPACE4-1': 0.0,
#                'SPACE5-1': 0.0},
#  'temperature': {'PLENUM-1': 16.375396018640348,
#                  'SPACE1-1': 18.831504670022376,
#                  'SPACE2-1': 18.541878694382117,
#                  'SPACE3-1': 17.929421756531585,
#                  'SPACE4-1': 18.04568266462399,
#                  'SPACE5-1': 19.211180555611186},
#  'terminate': False,
#  'time': datetime.datetime(1986, 1, 1, 16, 0),
#  'timestep': 31}
# {'System Node Dewpoint Temperature_Mixed Air Node 1': -9.355250061011468,
#  'System Node Humidity Ratio_Mixed Air Node 1': 0.0017301351392934887,
#  'System Node Mass Flow Rate_Main Cooling Coil 1 Water Inlet Node': 0.0,
#  'System Node Temperature_Mixed Air Node 1': 16.079406318697476,
#  'energy': 1545004.3577703112,
#  'occupancy': {'SPACE1-1': 0.0,
#                'SPACE2-1': 0.0,
#                'SPACE3-1': 0.0,
#                'SPACE4-1': 0.0,
#                'SPACE5-1': 0.0},
#  'temperature': {'PLENUM-1': 16.40696506350098,
#                  'SPACE1-1': 18.652966504740345,
#                  'SPACE2-1': 18.392434168956544,
#                  'SPACE3-1': 17.89954829235374,
#                  'SPACE4-1': 18.025403356704413,
#                  'SPACE5-1': 19.264828080887856},
#  'terminate': False,
#  'time': datetime.datetime(1986, 1, 1, 16, 30),
#  'timestep': 32}
# {'System Node Dewpoint Temperature_Mixed Air Node 1': -9.285598484753267,
#  'System Node Humidity Ratio_Mixed Air Node 1': 0.0017408408308729189,
#  'System Node Mass Flow Rate_Main Cooling Coil 1 Water Inlet Node': 0.0,
#  'System Node Temperature_Mixed Air Node 1': 16.110446516492996,
#  'energy': 1501275.4175122564,
#  'occupancy': {'SPACE1-1': 0.0,
#                'SPACE2-1': 0.0,
#                'SPACE3-1': 0.0,
#                'SPACE4-1': 0.0,
#                'SPACE5-1': 0.0},
#  'temperature': {'PLENUM-1': 16.40934155857752,
#                  'SPACE1-1': 18.43683909774152,
#                  'SPACE2-1': 18.251637194442026,
#                  'SPACE3-1': 17.855447899810382,
#                  'SPACE4-1': 17.961408883074334,
#                  'SPACE5-1': 19.310903866639116},
#  'terminate': False,
#  'time': datetime.datetime(1986, 1, 1, 17, 0),
#  'timestep': 33}
# {'System Node Dewpoint Temperature_Mixed Air Node 1': -9.225696389820857,
#  'System Node Humidity Ratio_Mixed Air Node 1': 0.001750096452575682,
#  'System Node Mass Flow Rate_Main Cooling Coil 1 Water Inlet Node': 0.0,
#  'System Node Temperature_Mixed Air Node 1': 16.112787822002495,
#  'energy': 1459011.0764233328,
#  'occupancy': {'SPACE1-1': 0.0,
#                'SPACE2-1': 0.0,
#                'SPACE3-1': 0.0,
#                'SPACE4-1': 0.0,
#                'SPACE5-1': 0.0},
#  'temperature': {'PLENUM-1': 16.389952491125282,
#                  'SPACE1-1': 18.280776887295982,
#                  'SPACE2-1': 18.149397907505403,
#                  'SPACE3-1': 17.83397935318303,
#                  'SPACE4-1': 17.920121757102663,
#                  'SPACE5-1': 19.350640843162328},
#  'terminate': False,
#  'time': datetime.datetime(1986, 1, 1, 17, 30),
#  'timestep': 34}
# {'System Node Dewpoint Temperature_Mixed Air Node 1': -9.182011541095548,
#  'System Node Humidity Ratio_Mixed Air Node 1': 0.0017568747623526036,
#  'System Node Mass Flow Rate_Main Cooling Coil 1 Water Inlet Node': 0.0,
#  'System Node Temperature_Mixed Air Node 1': 16.08865446485054,
#  'energy': 1444141.7500944324,
#  'occupancy': {'SPACE1-1': 0.0,
#                'SPACE2-1': 0.0,
#                'SPACE3-1': 0.0,
#                'SPACE4-1': 0.0,
#                'SPACE5-1': 0.0},
#  'temperature': {'PLENUM-1': 16.356782336466868,
#                  'SPACE1-1': 18.14813461390492,
#                  'SPACE2-1': 18.054362546309402,
#                  'SPACE3-1': 17.802879039034934,
#                  'SPACE4-1': 17.874688791555787,
#                  'SPACE5-1': 19.363562819869816},
#  'terminate': False,
#  'time': datetime.datetime(1986, 1, 1, 18, 0),
#  'timestep': 35}
# {'System Node Dewpoint Temperature_Mixed Air Node 1': -9.157379423575902,
#  'System Node Humidity Ratio_Mixed Air Node 1': 0.001760707422095396,
#  'System Node Mass Flow Rate_Main Cooling Coil 1 Water Inlet Node': 0.0,
#  'System Node Temperature_Mixed Air Node 1': 16.05097269506343,
#  'energy': 1434825.3932010531,
#  'occupancy': {'SPACE1-1': 0.0,
#                'SPACE2-1': 0.0,
#                'SPACE3-1': 0.0,
#                'SPACE4-1': 0.0,
#                'SPACE5-1': 0.0},
#  'temperature': {'PLENUM-1': 16.31312995327381,
#                  'SPACE1-1': 18.029956922112333,
#                  'SPACE2-1': 17.966856312932798,
#                  'SPACE3-1': 17.76484575264973,
#                  'SPACE4-1': 17.825311688961804,
#                  'SPACE5-1': 19.361333247366737},
#  'terminate': False,
#  'time': datetime.datetime(1986, 1, 1, 18, 30),
#  'timestep': 36}
# {'System Node Dewpoint Temperature_Mixed Air Node 1': -9.142310767574585,
#  'System Node Humidity Ratio_Mixed Air Node 1': 0.0017630557611000848,
#  'System Node Mass Flow Rate_Main Cooling Coil 1 Water Inlet Node': 0.0,
#  'System Node Temperature_Mixed Air Node 1': 16.00382728935307,
#  'energy': 1430077.4992494925,
#  'occupancy': {'SPACE1-1': 0.0,
#                'SPACE2-1': 0.0,
#                'SPACE3-1': 0.0,
#                'SPACE4-1': 0.0,
#                'SPACE5-1': 0.0},
#  'temperature': {'PLENUM-1': 16.26166867014784,
#                  'SPACE1-1': 17.895038375227532,
#                  'SPACE2-1': 17.86245418474413,
#                  'SPACE3-1': 17.694684904860164,
#                  'SPACE4-1': 17.750263082249514,
#                  'SPACE5-1': 19.31856095170354},
#  'terminate': False,
#  'time': datetime.datetime(1986, 1, 1, 19, 0),
#  'timestep': 37}
# {'System Node Dewpoint Temperature_Mixed Air Node 1': -9.127921644888447,
#  'System Node Humidity Ratio_Mixed Air Node 1': 0.001765300919771616,
#  'System Node Mass Flow Rate_Main Cooling Coil 1 Water Inlet Node': 0.0,
#  'System Node Temperature_Mixed Air Node 1': 15.949005845100414,
#  'energy': 1413820.848047605,
#  'occupancy': {'SPACE1-1': 0.0,
#                'SPACE2-1': 0.0,
#                'SPACE3-1': 0.0,
#                'SPACE4-1': 0.0,
#                'SPACE5-1': 0.0},
#  'temperature': {'PLENUM-1': 16.200841280368557,
#                  'SPACE1-1': 17.755432005061028,
#                  'SPACE2-1': 17.751302876264727,
#                  'SPACE3-1': 17.606430832096883,
#                  'SPACE4-1': 17.661891832201192,
#                  'SPACE5-1': 19.25098673204904},
#  'terminate': False,
#  'time': datetime.datetime(1986, 1, 1, 19, 30),
#  'timestep': 38}
# {'System Node Dewpoint Temperature_Mixed Air Node 1': -9.09261097724605,
#  'System Node Humidity Ratio_Mixed Air Node 1': 0.0017708215558360078,
#  'System Node Mass Flow Rate_Main Cooling Coil 1 Water Inlet Node': 0.0,
#  'System Node Temperature_Mixed Air Node 1': 15.898491342522522,
#  'energy': 1393742.670640265,
#  'occupancy': {'SPACE1-1': 0.0,
#                'SPACE2-1': 0.0,
#                'SPACE3-1': 0.0,
#                'SPACE4-1': 0.0,
#                'SPACE5-1': 0.0},
#  'temperature': {'PLENUM-1': 16.13206554260648,
#                  'SPACE1-1': 17.663533065133016,
#                  'SPACE2-1': 17.675975860151052,
#                  'SPACE3-1': 17.553385368072103,
#                  'SPACE4-1': 17.60412244290798,
#                  'SPACE5-1': 19.201647059442575},
#  'terminate': False,
#  'time': datetime.datetime(1986, 1, 1, 20, 0),
#  'timestep': 39}
# {'System Node Dewpoint Temperature_Mixed Air Node 1': -9.03368587791899,
#  'System Node Humidity Ratio_Mixed Air Node 1': 0.0017800695229003456,
#  'System Node Mass Flow Rate_Main Cooling Coil 1 Water Inlet Node': 0.0,
#  'System Node Temperature_Mixed Air Node 1': 15.84016726157079,
#  'energy': 1395713.0826110784,
#  'occupancy': {'SPACE1-1': 0.0,
#                'SPACE2-1': 0.0,
#                'SPACE3-1': 0.0,
#                'SPACE4-1': 0.0,
#                'SPACE5-1': 0.0},
#  'temperature': {'PLENUM-1': 16.06370350933988,
#                  'SPACE1-1': 17.6025618829244,
#                  'SPACE2-1': 17.62244783739724,
#                  'SPACE3-1': 17.522148752115093,
#                  'SPACE4-1': 17.563596806994596,
#                  'SPACE5-1': 19.163549375479466},
#  'terminate': False,
#  'time': datetime.datetime(1986, 1, 1, 20, 30),
#  'timestep': 40}
# {'System Node Dewpoint Temperature_Mixed Air Node 1': -8.963851069489635,
#  'System Node Humidity Ratio_Mixed Air Node 1': 0.0017919927704540919,
#  'System Node Mass Flow Rate_Main Cooling Coil 1 Water Inlet Node': 0.0,
#  'System Node Temperature_Mixed Air Node 1': 15.767865093417718,
#  'energy': 1407462.992984957,
#  'occupancy': {'SPACE1-1': 0.0,
#                'SPACE2-1': 0.0,
#                'SPACE3-1': 0.0,
#                'SPACE4-1': 0.0,
#                'SPACE5-1': 0.0},
#  'temperature': {'PLENUM-1': 16.001294394245225,
#                  'SPACE1-1': 17.58062029466037,
#                  'SPACE2-1': 17.601188185841856,
#                  'SPACE3-1': 17.52348964665688,
#                  'SPACE4-1': 17.551660566131186,
#                  'SPACE5-1': 19.173476924601466},
#  'terminate': False,
#  'time': datetime.datetime(1986, 1, 1, 21, 0),
#  'timestep': 41}
# {'System Node Dewpoint Temperature_Mixed Air Node 1': -8.883534470222116,
#  'System Node Humidity Ratio_Mixed Air Node 1': 0.0018056608823511374,
#  'System Node Mass Flow Rate_Main Cooling Coil 1 Water Inlet Node': 0.0,
#  'System Node Temperature_Mixed Air Node 1': 15.701417538521353,
#  'energy': 1436974.1088174803,
#  'occupancy': {'SPACE1-1': 0.0,
#                'SPACE2-1': 0.0,
#                'SPACE3-1': 0.0,
#                'SPACE4-1': 0.0,
#                'SPACE5-1': 0.0},
#  'temperature': {'PLENUM-1': 15.948598946507408,
#                  'SPACE1-1': 17.584041762534383,
#                  'SPACE2-1': 17.600061032179845,
#                  'SPACE3-1': 17.545177674895665,
#                  'SPACE4-1': 17.557342488239897,
#                  'SPACE5-1': 19.212926008123667},
#  'terminate': False,
#  'time': datetime.datetime(1986, 1, 1, 21, 30),
#  'timestep': 42}
# {'System Node Dewpoint Temperature_Mixed Air Node 1': -8.811929861728416,
#  'System Node Humidity Ratio_Mixed Air Node 1': 0.0018171080494654803,
#  'System Node Mass Flow Rate_Main Cooling Coil 1 Water Inlet Node': 0.0,
#  'System Node Temperature_Mixed Air Node 1': 15.65469536961776,
#  'energy': 1475508.6698686846,
#  'occupancy': {'SPACE1-1': 0.0,
#                'SPACE2-1': 0.0,
#                'SPACE3-1': 0.0,
#                'SPACE4-1': 0.0,
#                'SPACE5-1': 0.0},
#  'temperature': {'PLENUM-1': 15.905127146606942,
#                  'SPACE1-1': 17.538625777752497,
#                  'SPACE2-1': 17.55650026841344,
#                  'SPACE3-1': 17.51412366673739,
#                  'SPACE4-1': 17.519213005983897,
#                  'SPACE5-1': 19.183253787780313},
#  'terminate': False,
#  'time': datetime.datetime(1986, 1, 1, 22, 0),
#  'timestep': 43}
# {'System Node Dewpoint Temperature_Mixed Air Node 1': -8.77317975028843,
#  'System Node Humidity Ratio_Mixed Air Node 1': 0.0018233306768905579,
#  'System Node Mass Flow Rate_Main Cooling Coil 1 Water Inlet Node': 0.0,
#  'System Node Temperature_Mixed Air Node 1': 15.617038459005405,
#  'energy': 1479666.0445108677,
#  'occupancy': {'SPACE1-1': 0.0,
#                'SPACE2-1': 0.0,
#                'SPACE3-1': 0.0,
#                'SPACE4-1': 0.0,
#                'SPACE5-1': 0.0},
#  'temperature': {'PLENUM-1': 15.861465209502166,
#                  'SPACE1-1': 17.471842324955073,
#                  'SPACE2-1': 17.496345531424637,
#                  'SPACE3-1': 17.458638318204677,
#                  'SPACE4-1': 17.46361184069016,
#                  'SPACE5-1': 19.114794961572276},
#  'terminate': False,
#  'time': datetime.datetime(1986, 1, 1, 22, 30),
#  'timestep': 44}
# {'System Node Dewpoint Temperature_Mixed Air Node 1': -8.746968774032329,
#  'System Node Humidity Ratio_Mixed Air Node 1': 0.0018284760041568865,
#  'System Node Mass Flow Rate_Main Cooling Coil 1 Water Inlet Node': 0.0,
#  'System Node Temperature_Mixed Air Node 1': 15.56904318309235,
#  'energy': 1468945.6758892222,
#  'occupancy': {'SPACE1-1': 0.0,
#                'SPACE2-1': 0.0,
#                'SPACE3-1': 0.0,
#                'SPACE4-1': 0.0,
#                'SPACE5-1': 0.0},
#  'temperature': {'PLENUM-1': 15.816094394026974,
#                  'SPACE1-1': 17.4202117499461,
#                  'SPACE2-1': 17.449287857709972,
#                  'SPACE3-1': 17.413663537830956,
#                  'SPACE4-1': 17.420019625444922,
#                  'SPACE5-1': 19.07299589565902},
#  'terminate': False,
#  'time': datetime.datetime(1986, 1, 1, 23, 0),
#  'timestep': 45}
# {'System Node Dewpoint Temperature_Mixed Air Node 1': -8.686209798517188,
#  'System Node Humidity Ratio_Mixed Air Node 1': 0.0018392290221884557,
#  'System Node Mass Flow Rate_Main Cooling Coil 1 Water Inlet Node': 0.0,
#  'System Node Temperature_Mixed Air Node 1': 15.51937192262766,
#  'energy': 1467441.765189631,
#  'occupancy': {'SPACE1-1': 0.0,
#                'SPACE2-1': 0.0,
#                'SPACE3-1': 0.0,
#                'SPACE4-1': 0.0,
#                'SPACE5-1': 0.0},
#  'temperature': {'PLENUM-1': 15.772571176519772,
#                  'SPACE1-1': 17.375156019449353,
#                  'SPACE2-1': 17.406500677760803,
#                  'SPACE3-1': 17.37232835815333,
#                  'SPACE4-1': 17.379785117648243,
#                  'SPACE5-1': 19.04771136554344},
#  'terminate': False,
#  'time': datetime.datetime(1986, 1, 1, 23, 30),
#  'timestep': 46}
# {'System Node Dewpoint Temperature_Mixed Air Node 1': -8.602195595779918,
#  'System Node Humidity Ratio_Mixed Air Node 1': 0.0018528968325480068,
#  'System Node Mass Flow Rate_Main Cooling Coil 1 Water Inlet Node': 0.0,
#  'System Node Temperature_Mixed Air Node 1': 15.47664841810699,
#  'energy': 1469661.0203173389,
#  'occupancy': {'SPACE1-1': 0.0,
#                'SPACE2-1': 0.0,
#                'SPACE3-1': 0.0,
#                'SPACE4-1': 0.0,
#                'SPACE5-1': 0.0},
#  'temperature': {'PLENUM-1': 15.730511426624728,
#                  'SPACE1-1': 17.339938631346296,
#                  'SPACE2-1': 17.371622661811372,
#                  'SPACE3-1': 17.34007321206572,
#                  'SPACE4-1': 17.346809321180803,
#                  'SPACE5-1': 19.02721174414462},
#  'terminate': True,
#  'time': datetime.datetime(1986, 1, 2, 0, 0),
#  'timestep': 47}
# Done

# %% [markdown]
# <a id="code-new-state"></a>
# #### Code for using state variables that are not defined in IDF files

# %%
"""
This is an example of how to add your own states using COBS.
We show two new states: VAV position and CO2 concentration
"""
from cobs import Model
from pprint import pprint
from tqdm import tqdm
import matplotlib.pyplot as plt

Model.set_energyplus_folder("D:\\Software\\EnergyPlus\\")

# A dictionary formatted as {target sensor: state name}
# The target sensor is a tuple: (variable name, key value)
eplus_extra_states = {("Zone Air Terminal VAV Damper Position", "SPACE1-1 VAV Reheat"): "Space 1-1 VAV",
                      ("Zone Air Terminal VAV Damper Position", "SPACE2-1 VAV Reheat"): "Space 2-1 VAV",
                      ("Zone Air CO2 Concentration", "SPACE1-1"): "SPACE1-1 CO2",
                      ("Zone Air CO2 Concentration", "SPACE2-1"): "SPACE2-1 CO2"}

model = Model(idf_file_name="cobs/data/buildings/5ZoneAirCooled.idf",
              weather_file="cobs/data/weathers/USA_IL_Chicago-OHare.Intl.AP.725300_TMY3.epw",
              eplus_naming_dict=eplus_extra_states)

# Add these sensors to the IDF file (optional, if IDF already contains them, you can ignore it)
for key, _ in eplus_extra_states.items():
    model.add_configuration("Output:Variable",
                            {"Key Value": key[1], "Variable Name": key[0], "Reporting Frequency": "Timestep"})

# Add simulation of CO2 concentration. It is not included in 5ZoneAirCooled.idf, so I add it here
# You have to provide outdoor CO2 concentration for Energyplus to calculate indoor CO2 concentration
# Here I use 410.25 ppm as the outdoor CO2 level
model.add_configuration("Schedule:Constant",
                        {"Name": "Outdoor CO2 Schedule",
                         "Schedule Type Limits Name": "Any Number",
                         "Hourly Value": 410.25})
model.add_configuration("ZoneAirContaminantBalance",
                        {"Carbon Dioxide Concentration": "Yes",
                         "Outdoor Carbon Dioxide Schedule Name": "Outdoor CO2 Schedule"})

# Check current available state variables
pprint(model.get_current_state_variables())
# Out:
# [('System Node Dewpoint Temperature', 'Mixed Air Node 1'),
#  ('System Node Humidity Ratio', 'Mixed Air Node 1'),
#  ('System Node Humidity Ratio', 'OA Heating Coil 1 Air Outlet Node'),
#  ('System Node Humidity Ratio', 'OA Mixing Box 1 Inlet Node'),
#  ('System Node Humidity Ratio', 'VAV Sys 1 Outlet Node'),
#  ('System Node Mass Flow Rate', 'Main Cooling Coil 1 Water Inlet Node'),
#  ('System Node Mass Flow Rate', 'Main Heating Coil 1 Water Inlet Node'),
#  ('System Node Mass Flow Rate', 'OA Cooling Coil 1 Water Inlet Node'),
#  ('System Node Mass Flow Rate', 'OA Heating Coil 1 Air Outlet Node'),
#  ('System Node Mass Flow Rate', 'OA Heating Coil 1 Water Inlet Node'),
#  ('System Node Mass Flow Rate', 'OA Mixing Box 1 Inlet Node'),
#  ('System Node Mass Flow Rate', 'VAV Sys 1 Outlet Node'),
#  ('System Node Setpoint Temperature', 'OA Heating Coil 1 Air Outlet Node'),
#  ('System Node Setpoint Temperature', 'OA Mixing Box 1 Inlet Node'),
#  ('System Node Setpoint Temperature', 'VAV Sys 1 Outlet Node'),
#  ('System Node Temperature', 'Mixed Air Node 1'),
#  ('System Node Temperature', 'OA Cooling Coil 1 Water Inlet Node'),
#  ('System Node Temperature', 'OA Heating Coil 1 Air Outlet Node'),
#  ('System Node Temperature', 'OA Heating Coil 1 Water Inlet Node'),
#  ('System Node Temperature', 'OA Mixing Box 1 Inlet Node'),
#  ('System Node Temperature', 'VAV Sys 1 Outlet Node'),
#  ('Zone Air CO2 Concentration', 'SPACE1-1'),
#  ('Zone Air CO2 Concentration', 'SPACE2-1'),
#  ('Zone Air Terminal VAV Damper Position', 'SPACE1-1 VAV Reheat'),
#  ('Zone Air Terminal VAV Damper Position', 'SPACE2-1 VAV Reheat')]

# %%
# Simulate for 20 day, 60-minute timesteps
model.set_runperiod(20)
model.set_timestep(1)

# Store values for visualization
vav_1_pos = list()
vav_2_pos = list()

co2_1 = list()
co2_2 = list()

state = model.reset()

# Run simulation
with tqdm(total=model.get_total_timestep() - 1) as pbar:
    while not model.is_terminate():
        vav_1_pos.append(state["Space 1-1 VAV"])
        vav_2_pos.append(state["Space 2-1 VAV"])
        co2_1.append(state["SPACE1-1 CO2"])
        co2_2.append(state["SPACE2-1 CO2"])

        state = model.step(None)
        pbar.update(1)

# Show what is included in the state
pprint(state)

# Plot the result
plt.plot(vav_1_pos, label="Space 1-1 VAV")
plt.plot(vav_2_pos, label="Space 2-1 VAV")
plt.legend()
plt.show()

plt.plot(co2_1, label="Space 1-1 CO2")
plt.plot(co2_2, label="Space 2-1 CO2")
plt.legend()
plt.show()
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 479/479 [00:03<00:00, 148.05it/s]
# {'SPACE1-1 CO2': 788.4153498790545,
#  'SPACE2-1 CO2': 794.5009497948214,
#  'Space 1-1 VAV': 0.3,
#  'Space 2-1 VAV': 0.3,
#  'System Node Dewpoint Temperature_Mixed Air Node 1': 1.0977314980974429,
#  'System Node Humidity Ratio_Mixed Air Node 1': 0.004185270256151848,
#  'System Node Humidity Ratio_OA Heating Coil 1 Air Outlet Node': 0.0029943091930087523,
#  'System Node Humidity Ratio_OA Mixing Box 1 Inlet Node': 0.0029943091930087523,
#  'System Node Humidity Ratio_VAV Sys 1 Outlet Node': 0.004185270256151848,
#  'System Node Mass Flow Rate_Main Cooling Coil 1 Water Inlet Node': 0.0,
#  'System Node Mass Flow Rate_Main Heating Coil 1 Water Inlet Node': 0.0,
#  'System Node Mass Flow Rate_OA Cooling Coil 1 Water Inlet Node': 0.0,
#  'System Node Mass Flow Rate_OA Heating Coil 1 Air Outlet Node': 0.00621144618492455,
#  'System Node Mass Flow Rate_OA Heating Coil 1 Water Inlet Node': 0.0,
#  'System Node Mass Flow Rate_OA Mixing Box 1 Inlet Node': 0.00621144618492455,
#  'System Node Mass Flow Rate_VAV Sys 1 Outlet Node': 0.3603613080468873,
#  'System Node Setpoint Temperature_OA Heating Coil 1 Air Outlet Node': 4.5,
#  'System Node Setpoint Temperature_OA Mixing Box 1 Inlet Node': 11.5,
#  'System Node Setpoint Temperature_VAV Sys 1 Outlet Node': 16.0,
#  'System Node Temperature_Mixed Air Node 1': 18.991638055330824,
#  'System Node Temperature_OA Cooling Coil 1 Water Inlet Node': 7.219999999999999,
#  'System Node Temperature_OA Heating Coil 1 Air Outlet Node': -1.1,
#  'System Node Temperature_OA Heating Coil 1 Water Inlet Node': 82.0,
#  'System Node Temperature_OA Mixing Box 1 Inlet Node': -1.1,
#  'System Node Temperature_VAV Sys 1 Outlet Node': 19.99483007140889,
#  'energy': 1657638.7786369447,
#  'occupancy': {'SPACE1-1': 0.0,
#                'SPACE2-1': 0.0,
#                'SPACE3-1': 0.0,
#                'SPACE4-1': 0.0,
#                'SPACE5-1': 0.0},
#  'temperature': {'PLENUM-1': 19.35192939054375,
#                  'SPACE1-1': 18.82091129870068,
#                  'SPACE2-1': 19.04241301472719,
#                  'SPACE3-1': 18.77192955446994,
#                  'SPACE4-1': 19.069796665178707,
#                  'SPACE5-1': 20.08684779385139},
#  'terminate': True,
#  'time': datetime.datetime(1986, 1, 21, 0, 0),
#  'timestep': 479}

# %% [markdown]
# <a id="action"></a>
# ### Wrapping your action
#
# By using COBS, you can take many types of actions, such as changing the control setpoint, or even directly overwriting sensor readings (although it is not recommended). To perform a valid action, you have to know the actuator name beforehand. You need to provide the IDF object type, control type, and the key for the corresponding IDF object. These three pieces of information can be retrieved from the `*.edd` file after a successful run. If you don't have this `*.edd` file generated after the experiment, try adding the following in your IDF file and run the experiment again.
# >```
# >Output:EnergyManagementSystem,
# >    Verbose,    ! Actuator Availability Dictionary Reporting
# >    Verbose,    ! Internal Variable Availability Dictionary Reporting
# >    ErrorsOnly; ! EnergyPlus Runtime Language Debug Output Level
# >```
#
# The `*.edd` file will look like this:
# >! <EnergyManagementSystem:Actuator Available>, **Component Unique Name**, **Component Type**,  **Control Type**, Units
# >
# >EnergyManagementSystem:Actuator Available,**Environment**,**Weather Data**,**Outdoor Dry Bulb**,[C]
# >
# >EnergyManagementSystem:Actuator Available,**Environment**,**Weather Data**,**Outdoor Dew Point**,[C]
# >
# >EnergyManagementSystem:Actuator Available,**Environment**,**Weather Data**,**Outdoor Relative Humidity**,[%]
# >
# >...
#
# where the **component type** is the IDF object type and **Component Unique Name** is the key of the corresponding IDF object.
#
# Usually we generate an empty schedule and link it to the object we want to control, and then modify the value inside this schedule to control the setpoint.
#
# Each timestep, the environment takes a list of actions. Each action should be presented as a dictionary with this format:
# ```python
# {
#     "value": 10,                          # Set to what value
#     "start_time": state["timestep"] + 1,  # When this action will be triggered (in timestep)
#     "end_time": state["timestep"] + 2,    # (optional) When this action will be discarded (in timestep)
#     "priority": 0,                        # The priority of this action, lower means higher priority
#     "component_type": "Weather Data",     # Component Type in *.edd file
#     "control_type": "Outdoor Dry Bulb",   # Control Type in *.edd file
#     "actuator_key": "Environment"         # Component Unique Name in *.edd file
# }
# ```
#
# In case there is a conflict, the action with higher priority (lower priority value) will be performed.
#
# [Back to top](#table-of-contents)

# %%
# This is the same example as before, but here we add a control for the VAV position in SPACE 1-1
from cobs import Model
from pprint import pprint
from tqdm import tqdm
import matplotlib.pyplot as plt

Model.set_energyplus_folder("D:\\Software\\EnergyPlus\\")

eplus_extra_states = {("Zone Air Terminal VAV Damper Position", "SPACE1-1 VAV Reheat"): "Space 1-1 VAV",
                      ("Zone Air Terminal VAV Damper Position", "SPACE2-1 VAV Reheat"): "Space 2-1 VAV",
                      ("Zone Air CO2 Concentration", "SPACE1-1"): "SPACE1-1 CO2",
                      ("Zone Air CO2 Concentration", "SPACE2-1"): "SPACE2-1 CO2"}

model = Model(idf_file_name="cobs/data/buildings/5ZoneAirCooled.idf",
              weather_file="cobs/data/weathers/USA_IL_Chicago-OHare.Intl.AP.725300_TMY3.epw",
              eplus_naming_dict=eplus_extra_states)

for key, _ in eplus_extra_states.items():
    model.add_configuration("Output:Variable",
                            {"Key Value": key[1], "Variable Name": key[0], "Reporting Frequency": "Timestep"})

model.add_configuration("Schedule:Constant",
                        {"Name": "Outdoor CO2 Schedule",
                         "Schedule Type Limits Name": "Any Number",
                         "Hourly Value": 410.25})
model.add_configuration("ZoneAirContaminantBalance",
                        {"Carbon Dioxide Concentration": "Yes",
                         "Outdoor Carbon Dioxide Schedule Name": "Outdoor CO2 Schedule"})

# ===== NEW CODE =====
# Because the SPACE1-1 VAV Customized Schedule does not exist (I added to control the VAV), so add to the IDF
model.add_configuration("Schedule:Constant",
                        {"Name": "SPACE1-1 VAV Customized Schedule",
                         "Schedule Type Limits Name": "Fraction",
                         "Hourly Value": 0})

# Overwrite existing VAV control policy to get control over the minimum VAV position
model.edit_configuration(idf_header_name="AirTerminal:SingleDuct:VAV:Reheat",
                         identifier={"Name": "SPACE1-1 VAV Reheat"},
                         update_values={"Zone Minimum Air Flow Input Method": "Scheduled",
                                        "Minimum Air Flow Fraction Schedule Name": "SPACE1-1 VAV Customized Schedule"})
# ===== END OF NEW CODE =====

model.set_runperiod(20)
model.set_timestep(1)

# Store values for visualization
vav_1_pos = list()
vav_2_pos = list()
co2_1 = list()
co2_2 = list()

# ===== NEW CODE =====
vav_1_stpt = 0.8  # In this example, I force the SPACE1-1 VAV to 80% open at all times
# ===== END OF NEW CODE =====

state = model.reset()

# Run simulation
with tqdm(total=model.get_total_timestep() - 1) as pbar:
    while not model.is_terminate():
        vav_1_pos.append(state["Space 1-1 VAV"])
        vav_2_pos.append(state["Space 2-1 VAV"])
        co2_1.append(state["SPACE1-1 CO2"])
        co2_2.append(state["SPACE2-1 CO2"])

        # ===== NEW CODE =====
        # Define our actions
        actions = list()
        actions.append({"priority": 0,
                        "component_type": "Schedule:Constant",
                        "control_type": "Schedule Value",
                        "actuator_key": "SPACE1-1 VAV Customized Schedule",
                        "value": vav_1_stpt,
                        "start_time": state['timestep'] + 1})
        state = model.step(actions)
        # ===== END OF NEW CODE =====
        pbar.update(1)

# Visualize the result
plt.plot(vav_1_pos, label="Space 1-1 VAV")
plt.plot(vav_2_pos, label="Space 2-1 VAV")
plt.legend()
plt.show()

plt.plot(co2_1, label="Space 1-1 CO2")
plt.plot(co2_2, label="Space 2-1 CO2")
plt.legend()
plt.show()
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 479/479 [00:02<00:00, 176.83it/s]

# %%
# Example 2 - Change the zonal heating and cooling setpoint
from cobs import Model
from pprint import pprint
from tqdm import tqdm
import pandas as pd
import matplotlib.pyplot as plt

Model.set_energyplus_folder("D:\\Software\\EnergyPlus\\")

model = Model(idf_file_name="cobs/data/buildings/5ZoneAirCooled.idf",
              weather_file="cobs/data/weathers/USA_IL_Chicago-OHare.Intl.AP.725300_TMY3.epw")

state = model.reset()
# This time we log the total energy consumption of the building
total_energy = 0
# Let's plot the room temperature to see if it follows the setpoint
temperatures = list()

with tqdm(total=model.get_total_timestep() - 1) as pbar:
    while not model.is_terminate():
        total_energy += state["energy"]
        temperatures.append(state["temperature"])
        
        # Generate actions to control all setpoints
        actions = list()
        for zone, temp in state["temperature"].items():
            
            # The PLENUM-1 has no heating/cooling system, so ignore it
            if zone == "PLENUM-1":
                continue
            
            # Assuming we want to keep the temperature between 21 and 23 degrees Celsius
            actions.append({"value": 23,
                            "start_time": state["timestep"] + 1,
                            "priority": 0,
                            "component_type": "Zone Temperature Control",
                            "control_type": "Cooling Setpoint",
                            "actuator_key": zone})
            actions.append({"value": 21,
                            "start_time": state["timestep"] + 1,
                            "priority": 0,
                            "component_type": "Zone Temperature Control",
                            "control_type": "Heating Setpoint",
                            "actuator_key": zone})
        state = model.step(actions)
        pbar.update(1)

total_energy += state["energy"]
temperatures.append(state["temperature"])

# Visualize the result
print(f"Total energy used: {total_energy}J ({total_energy / 3600000:.2f} kWh)")
pd.DataFrame(temperatures).plot()
plt.show()
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 1439/1439 [00:08<00:00, 169.15it/s]
# Total energy used: 633474197.1800121J (175.97 kWh)

# %%
# Repeat the experiment where we do not control the setpoint this time
state = model.reset()
total_energy = 0
temperatures = list()
with tqdm(total=model.get_total_timestep() - 1) as pbar:
    while not model.is_terminate():
        total_energy += state["energy"]
        temperatures.append(state["temperature"])
        state = model.step(None)
        pbar.update(1)

total_energy += state["energy"]
temperatures.append(state["temperature"])

print(f"Total energy used: {total_energy}J ({total_energy / 3600000:.2f} kWh)")
pd.DataFrame(temperatures).plot()
plt.show()
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 1439/1439 [00:07<00:00, 198.71it/s]
# Total energy used: 104017375.7172054J (28.89 kWh)

# %% [markdown]
# <a id="environment"></a>
# ### Defining the environment
#
# After the state and action are defined properly, we need to tweak some environment parameters, such as the experiment duration and the number of timesteps per hour. We can do this using these methods:
# 1. `COBS.Model.set_runperiod(days)`
# 2. `COBS.Model.set_timestep(timestep_per_hour)`
#
# It is also possible to specify the starting year, month, day of the experiment. Details can be found [here](https://cobs-platform.github.io/modules.html#cobs.model.Model.set_runperiod).
#
# You can also let COBS calculate the reward and return it in the state. However, this method does not work inside the Jupyter Notebook. Please try the code in a `*.py` file instead.
#
# [Back to top](#table-of-contents)

# %%
# Example shows how to change experiment settings
from cobs import Model
from tqdm import tqdm

Model.set_energyplus_folder("D:\\Software\\EnergyPlus\\")

model = Model(idf_file_name="cobs/data/buildings/5ZoneAirCooled.idf",
              weather_file="cobs/data/weathers/USA_IL_Chicago-OHare.Intl.AP.725300_TMY3.epw")

# a 20-day simulation starting from 7 June 2021
model.set_runperiod(20, start_year=2021, start_month=6, start_day=7, specify_year=True)
model.set_timestep(10)

# Remove all state variables because we do not need them
model.select_state_variables()
print(f"Selected state variables: {model.get_current_state_variables()}")

# Run the experiment and log the reward
state = model.reset()
print(f"Experiment start date {state['time']}")

with tqdm(total=model.get_total_timestep() - 1) as pbar:
    while not model.is_terminate():
        state = model.step(None)
        pbar.update(1)

print(f"Experiment end date {state['time']}")
# Out:
# Selected state variables: []
#   1%|▍                                                                              | 29/4799 [00:00<00:16, 285.07it/s]
# Experiment start date 1979-06-07 00:06:00
# 100%|█████████████████████████████████████████████████████████████████████████████| 4799/4799 [00:17<00:00, 273.32it/s]
# Experiment end date 1979-06-27 00:00:00

# %%
# Example shows how to define reward. Please run this as a *.py file
from cobs import Model
from cobs import OccupancyGenerator as OG
import numpy as np

class TestReward:
    def reward(self, state, actions):
        return state["timestep"] * 2

Model.set_energyplus_folder("D:\\Software\\EnergyPlus\\")

if __name__ == '__main__':

    model = Model(idf_file_name="data/buildings/5ZoneAirCooled.idf",
                  weather_file="data/weathers/USA_IL_Chicago-OHare.Intl.AP.725300_TMY3.epw",
                  reward=TestReward())
    model.reset()
    while not model.is_terminate():
        state = model.step(None)
    print(state)

# %% [markdown]
# ## Example of Implementing Naive Sarsa Agent using COBS
# In this naive example, we present how to implement a naive sarsa agent, with the following design:
# - **Environment**: Five zone air cooled building `5ZoneAirCooled.idf` from the EnergyPlus. Simulate from Jan 1 to Jan 31.
# - **State**: Two state variables.
#     - Average indoor temperature grouped into 16 discrete bins (integer value between 15 and 30).
#     - Current hour of the day (only care about 9-17).
# - **Action**: Temperature heating setpoint (integer value between 15 and 30).
# - **Reward**: The negation of the building energy cost.
#
# This experiment settings might not makes sense, but it showcasing how to use COBS.

# %%
from cobs import Model
from pprint import pprint
from tqdm.notebook import tqdm_notebook as tqdm
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from DQN import *
os.chdir("/mnt/c/Softwares/COBS")

Model.set_energyplus_folder("/usr/local/EnergyPlus-9-3-0/")

class SarsaAgent:
    def __init__(self):
        # Initialize the Q values randomly
        self.q = np.random.random((16 * 8, 16))
        self.last_action = None
        self.last_state = None
        self.epsilon = 0.05
        self.alpha = 0.5
        self.gamma = 1
    
    def take_action(self, state):
        actions = list()
        # Ignore non-business hour
        if state["time"].hour < 9 or state["time"].hour >= 17:
            return actions
        
        # Take actions by epsilon-greedy method
        setpoint = 0
        self.last_state = int(np.round((sum(state["temperature"].values()) - state["temperature"]["FirstFloor_Plenum"] - 
                                       state["temperature"]["MidFloor_Plenum"] - state["temperature"]["TopFloor_Plenum"]) / 15) - 15 + \
                              (state["time"].hour - 9) * 16)
        if np.random.random() < self.epsilon:
            setpoint = np.random.choice(range(15, 31))
        else:
            setpoint = np.argmax(self.q[self.last_state, :]) + 15
        
        
        # Encode the action
        for zone, temp in state["temperature"].items():
            # The PLENUM-1 has no heating/cooling system, so ignore it
            if "Plenum" in zone:
                continue
            actions.append({"value": setpoint,
                            "start_time": state["timestep"],
                            "priority": 0,
                            "component_type": "Zone Temperature Control",
                            "control_type": "Heating Setpoint",
                            "actuator_key": zone})
            actions.append({"value": 40,
                            "start_time": state["timestep"],
                            "priority": 0,
                            "component_type": "Zone Temperature Control",
                            "control_type": "Cooling Setpoint",
                            "actuator_key": zone}) 
#             actions.append({"value": setpoint,
#                             "start_time": state["timestep"],
#                             "priority": 0,
#                             "component_type": "System Node Setpoint",
#                             "control_type": "Temperature Setpoint",
#                             "actuator_key": "VAV_1 SUPPLY EQUIPMENT OUTLET NODE"})
#             actions.append({"value": setpoint,
#                             "start_time": state["timestep"],
#                             "priority": 0,
#                             "component_type": "System Node Setpoint",
#                             "control_type": "Temperature Setpoint",
#                             "actuator_key": "VAV_2 SUPPLY EQUIPMENT OUTLET NODE"})
#             actions.append({"value": setpoint,
#                             "start_time": state["timestep"],
#                             "priority": 0,
#                             "component_type": "System Node Setpoint",
#                             "control_type": "Temperature Setpoint",
#                             "actuator_key": "VAV_3 SUPPLY EQUIPMENT OUTLET NODE"})
    
        return actions

    def start(self, state):
        encoded_a_ = self.take_action(state)
        self.last_action = encoded_a_[0]["value"] if encoded_a_ else None
        return encoded_a_
        
    def step(self, state):
        a = self.last_action
        s = self.last_state
        encoded_a_ = self.take_action(state)
        a_ = encoded_a_[0]["value"] if encoded_a_ else None
        s_ = self.last_state

        if a is not None and a_ is not None:
            # Update Q
            self.q[s, a - 15] += self.alpha * (-state["HVAC Power"] + self.gamma * self.q[s_, a_ - 15] - self.q[s, a - 15])

        self.last_action = a_
        return encoded_a_

if __name__ == '__main__':
    idf_files_path = "/mnt/c/users/Dave/Downloads/idf-sample-files/"
    model = setup_env(idf_files_path + "2020/RefBldgMediumOfficeNew2004_Chicago.idf",
                    "cobs/data/weathers/USA_IL_Chicago-OHare.Intl.AP.725300_TMY3.epw",
                    num_days=14,
                    timestep=1)
    agent = SarsaAgent()
    
    num_episode = 1
    g = np.zeros(num_episode)

    with tqdm(total=model.get_total_timestep() - 1) as pbar:
        for i in tqdm(range(num_episode)):
            pbar.reset()
            state = model.reset()
            action = agent.start(state)
            print(action, state['temperature'])
            if 9 <= state["time"].hour < 17:
                g[i] += state["HVAC Power"]

            while not model.is_terminate():
                state = model.step(action)
                print('------------------------------------------------------------------------------------------------------------')
                print(state['timestep'])
                print(state['temperature'])
                action = agent.step(state)
                print(action)
                if 9 <= state["time"].hour < 17:
                    g[i] += state["HVAC Power"]
                pbar.update(1)
    
    # Expect to see a decrease of total energy use
    plt.plot(g)
    plt.show()
# Out:
#   0%|                                                                                           | 0/335 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/335 [00:00<?, ?it/s]
# EnergyPlus Starting
# EnergyPlus, Version 9.3.0-baff08990c, YMD=2022.03.23 10:29
# Initializing Response Factors
# Calculating CTFs for "STEEL FRAME NON-RES EXT WALL", Construction # 1
# Calculating CTFs for "IEAD NON-RES ROOF", Construction # 2
# Calculating CTFs for "EXT-SLAB", Construction # 3
# Calculating CTFs for "INT-WALLS", Construction # 4
# Calculating CTFs for "INT-FLOOR-TOPSIDE", Construction # 5
# Calculating CTFs for "DROPCEILING", Construction # 8
# Calculating CTFs for "INTERIORFURNISHINGS", Construction # 9
# Initializing Window Optical Properties
# Initializing Solar Calculations
# Allocate Solar Module Arrays
# Initializing Zone and Enclosure Report Variables
# Initializing Surface (Shading) Report Variables
# Determining Shadowing Combinations
# Computing Window Shade Absorption Factors
# Proceeding with Initializing Solar Calculations
# Initializing Surfaces
# Initializing Outdoor environment for Surfaces
# Setting up Surface Reporting Variables
# Initializing Temperature and Flux Histories
# Initializing Window Shading
# Computing Interior Absorption Factors
# Computing Interior Diffuse Solar Absorption Factors
# Computing Interior Diffuse Solar Exchange through Interzone Windows
# Initializing Solar Heat Gains
# Initializing Internal Heat Gains
# Initializing Interior Solar Distribution
# Initializing Interior Convection Coefficients
# Gathering Information for Predefined Reporting
# Completed Initializing Surface Heat Balance
# Calculate Outside Surface Heat Balance
# Calculate Inside Surface Heat Balance
# Calculate Air Heat Balance
# Initializing HVAC
# Warming up
# Warming up
# Warming up
# Warming up
# Warming up
# Warming up
# Performing Zone Sizing Simulation
# ...for Sizing Period: #1 CHICAGO ANN HTG 99.6% CONDNS DB
# Warming up
# Warming up
# Warming up
# Warming up
# Warming up
# Warming up
# Performing Zone Sizing Simulation
# ...for Sizing Period: #2 CHICAGO ANN CLG .4% CONDNS WB=>MDB
# Calculating System sizing
# ...for Sizing Period: #1 CHICAGO ANN HTG 99.6% CONDNS DB
# Calculating System sizing
# ...for Sizing Period: #2 CHICAGO ANN CLG .4% CONDNS WB=>MDB
# Adjusting Air System Sizing
# Adjusting Standard 62.1 Ventilation Sizing
# Initializing Simulation
# Reporting Surfaces
#   0%|▏                                                                                  | 1/335 [00:00<05:01,  1.11it/s]
# Beginning Primary Simulation
# Initializing New Environment Parameters
# Warming up {1}
# Warming up {2}
# Warming up {3}
# Warming up {4}
# Warming up {5}
# Warming up {6}
# Warming up {7}
# Starting Simulation at 07/01/2007 for ANNUAL
# [] {'Core_bottom': 24.641447714458163, 'Core_mid': 26.37255661462732, 'Core_top': 25.929800569704557, 'FirstFloor_Plenum': 24.612469238050416, 'MidFloor_Plenum': 25.283185677452416, 'Perimeter_bot_ZN_1': 23.451915774728924, 'Perimeter_bot_ZN_2': 23.41179395253131, 'Perimeter_bot_ZN_3': 23.427613508611916, 'Perimeter_bot_ZN_4': 23.437912588150873, 'Perimeter_mid_ZN_1': 24.84213561729552, 'Perimeter_mid_ZN_2': 24.78691133338664, 'Perimeter_mid_ZN_3': 24.81037500193137, 'Perimeter_mid_ZN_4': 24.81021406188121, 'Perimeter_top_ZN_1': 24.539037266974983, 'Perimeter_top_ZN_2': 24.48205468342624, 'Perimeter_top_ZN_3': 24.508481209333155, 'Perimeter_top_ZN_4': 24.507324489921846, 'TopFloor_Plenum': 23.118302659106533}
# ------------------------------------------------------------------------------------------------------------
# 1
# {'Core_bottom': 24.622481802116393, 'Core_mid': 26.355286210237537, 'Core_top': 25.852640024646355, 'FirstFloor_Plenum': 24.576820009140683, 'MidFloor_Plenum': 25.249979629725203, 'Perimeter_bot_ZN_1': 23.342845500796873, 'Perimeter_bot_ZN_2': 23.30312941008354, 'Perimeter_bot_ZN_3': 23.322883424584337, 'Perimeter_bot_ZN_4': 23.316314592506206, 'Perimeter_mid_ZN_1': 24.73695563754401, 'Perimeter_mid_ZN_2': 24.678157646795608, 'Perimeter_mid_ZN_3': 24.7097788424608, 'Perimeter_mid_ZN_4': 24.698426277055855, 'Perimeter_top_ZN_1': 24.400072879927496, 'Perimeter_top_ZN_2': 24.339201235023708, 'Perimeter_top_ZN_3': 24.366513261158797, 'Perimeter_top_ZN_4': 24.362512753026166, 'TopFloor_Plenum': 22.892313301119483}
# []
# ------------------------------------------------------------------------------------------------------------
# 2
# {'Core_bottom': 24.602577318284307, 'Core_mid': 26.335418977822794, 'Core_top': 25.77363293785633, 'FirstFloor_Plenum': 24.540561309142138, 'MidFloor_Plenum': 25.21396926545197, 'Perimeter_bot_ZN_1': 23.25372849492085, 'Perimeter_bot_ZN_2': 23.206530053336813, 'Perimeter_bot_ZN_3': 23.235277914678353, 'Perimeter_bot_ZN_4': 23.218051069368308, 'Perimeter_mid_ZN_1': 24.64520757189356, 'Perimeter_mid_ZN_2': 24.583171326018547, 'Perimeter_mid_ZN_3': 24.622258208634683, 'Perimeter_mid_ZN_4': 24.600999634856155, 'Perimeter_top_ZN_1': 24.269248805086068, 'Perimeter_top_ZN_2': 24.207866708519465, 'Perimeter_top_ZN_3': 24.243691282568065, 'Perimeter_top_ZN_4': 24.229928911344583, 'TopFloor_Plenum': 22.682155441081427}
# []
# ------------------------------------------------------------------------------------------------------------
# 3
# {'Core_bottom': 24.581920107396957, 'Core_mid': 26.313187992004156, 'Core_top': 25.69401351142573, 'FirstFloor_Plenum': 24.50222149205498, 'MidFloor_Plenum': 25.174389018446544, 'Perimeter_bot_ZN_1': 23.155827630094823, 'Perimeter_bot_ZN_2': 23.105999391052826, 'Perimeter_bot_ZN_3': 23.142607258126517, 'Perimeter_bot_ZN_4': 23.11488637594427, 'Perimeter_mid_ZN_1': 24.547077151345164, 'Perimeter_mid_ZN_2': 24.481663172106227, 'Perimeter_mid_ZN_3': 24.52830679331072, 'Perimeter_mid_ZN_4': 24.498378243829976, 'Perimeter_top_ZN_1': 24.135762688856815, 'Perimeter_top_ZN_2': 24.07132303675714, 'Perimeter_top_ZN_3': 24.11287645384028, 'Perimeter_top_ZN_4': 24.092247875847264, 'TopFloor_Plenum': 22.484745459318585}
# []
# ------------------------------------------------------------------------------------------------------------
# 4
# {'Core_bottom': 24.560306096423634, 'Core_mid': 26.288473356550394, 'Core_top': 25.612869683343575, 'FirstFloor_Plenum': 24.46195367749916, 'MidFloor_Plenum': 25.131272706754302, 'Perimeter_bot_ZN_1': 23.06099999553871, 'Perimeter_bot_ZN_2': 23.007566261972254, 'Perimeter_bot_ZN_3': 23.048707614417264, 'Perimeter_bot_ZN_4': 23.014902378725715, 'Perimeter_mid_ZN_1': 24.450495743395024, 'Perimeter_mid_ZN_2': 24.381804505330397, 'Perimeter_mid_ZN_3': 24.437561763167007, 'Perimeter_mid_ZN_4': 24.39749675797106, 'Perimeter_top_ZN_1': 24.002921719566483, 'Perimeter_top_ZN_2': 23.936148143124143, 'Perimeter_top_ZN_3': 23.988108254694904, 'Perimeter_top_ZN_4': 23.956193777401456, 'TopFloor_Plenum': 22.29606028804193}
# []
# ------------------------------------------------------------------------------------------------------------
# 5
# {'Core_bottom': 24.54058566052413, 'Core_mid': 26.264268970982254, 'Core_top': 25.533017561331846, 'FirstFloor_Plenum': 24.432806647792027, 'MidFloor_Plenum': 25.097795547417807, 'Perimeter_bot_ZN_1': 23.046373317263747, 'Perimeter_bot_ZN_2': 23.00356350803523, 'Perimeter_bot_ZN_3': 23.0405132924426, 'Perimeter_bot_ZN_4': 22.99346666235034, 'Perimeter_mid_ZN_1': 24.43437480846853, 'Perimeter_mid_ZN_2': 24.37571401148731, 'Perimeter_mid_ZN_3': 24.425006871603607, 'Perimeter_mid_ZN_4': 24.372149324785408, 'Perimeter_top_ZN_1': 23.94743664639306, 'Perimeter_top_ZN_2': 23.891334816656638, 'Perimeter_top_ZN_3': 23.93590712744015, 'Perimeter_top_ZN_4': 23.893793305182886, 'TopFloor_Plenum': 22.1633538288538}
# []
# ------------------------------------------------------------------------------------------------------------
# 6
# {'Core_bottom': 24.528790333503444, 'Core_mid': 26.24642957377224, 'Core_top': 25.464807341277364, 'FirstFloor_Plenum': 24.409994125127692, 'MidFloor_Plenum': 25.070452212065835, 'Perimeter_bot_ZN_1': 23.070592506516444, 'Perimeter_bot_ZN_2': 23.03355109682929, 'Perimeter_bot_ZN_3': 23.07779587999057, 'Perimeter_bot_ZN_4': 23.024544592978348, 'Perimeter_mid_ZN_1': 24.4458328416021, 'Perimeter_mid_ZN_2': 24.38814455498265, 'Perimeter_mid_ZN_3': 24.443651579281408, 'Perimeter_mid_ZN_4': 24.388282923740924, 'Perimeter_top_ZN_1': 23.925710513555995, 'Perimeter_top_ZN_2': 23.86724433250943, 'Perimeter_top_ZN_3': 23.91525905351005, 'Perimeter_top_ZN_4': 23.874328163456408, 'TopFloor_Plenum': 22.054132806335065}
# []
# ------------------------------------------------------------------------------------------------------------
# 7
# {'Core_bottom': 24.533644499562843, 'Core_mid': 26.243898627529454, 'Core_top': 25.416802161713424, 'FirstFloor_Plenum': 24.412020280526637, 'MidFloor_Plenum': 25.071047396001212, 'Perimeter_bot_ZN_1': 23.294147728510637, 'Perimeter_bot_ZN_2': 23.426164006850975, 'Perimeter_bot_ZN_3': 23.330238455675882, 'Perimeter_bot_ZN_4': 23.25173811152689, 'Perimeter_mid_ZN_1': 24.642745411265153, 'Perimeter_mid_ZN_2': 24.740363736605207, 'Perimeter_mid_ZN_3': 24.668180015737043, 'Perimeter_mid_ZN_4': 24.589567062685656, 'Perimeter_top_ZN_1': 24.08351958557383, 'Perimeter_top_ZN_2': 24.177671054365685, 'Perimeter_top_ZN_3': 24.099416463551343, 'Perimeter_top_ZN_4': 24.03788802767739, 'TopFloor_Plenum': 22.00085839311814}
# []
# ------------------------------------------------------------------------------------------------------------
# 8
# {'Core_bottom': 24.554229683271036, 'Core_mid': 26.25665579136758, 'Core_top': 25.39609390627886, 'FirstFloor_Plenum': 24.44866281792761, 'MidFloor_Plenum': 25.114318602365906, 'Perimeter_bot_ZN_1': 23.606721007488023, 'Perimeter_bot_ZN_2': 23.810949636747544, 'Perimeter_bot_ZN_3': 23.63002715539168, 'Perimeter_bot_ZN_4': 23.573121884091695, 'Perimeter_mid_ZN_1': 24.925613773588765, 'Perimeter_mid_ZN_2': 25.094100291981665, 'Perimeter_mid_ZN_3': 24.940046899972245, 'Perimeter_mid_ZN_4': 24.88034890411233, 'Perimeter_top_ZN_1': 24.328109736234794, 'Perimeter_top_ZN_2': 24.491929412503914, 'Perimeter_top_ZN_3': 24.33362020496416, 'Perimeter_top_ZN_4': 24.292124829079413, 'TopFloor_Plenum': 22.101774900974604}
# [{'value': 22, 'start_time': 8, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Core_bottom'}, {'value': 40, 'start_time': 8, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Core_bottom'}, {'value': 22, 'start_time': 8, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Core_mid'}, {'value': 40, 'start_time': 8, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Core_mid'}, {'value': 22, 'start_time': 8, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Core_top'}, {'value': 40, 'start_time': 8, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Core_top'}, {'value': 22, 'start_time': 8, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_bot_ZN_1'}, {'value': 40, 'start_time': 8, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_bot_ZN_1'}, {'value': 22, 'start_time': 8, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_bot_ZN_2'}, {'value': 40, 'start_time': 8, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_bot_ZN_2'}, {'value': 22, 'start_time': 8, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_bot_ZN_3'}, {'value': 40, 'start_time': 8, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_bot_ZN_3'}, {'value': 22, 'start_time': 8, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_bot_ZN_4'}, {'value': 40, 'start_time': 8, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_bot_ZN_4'}, {'value': 22, 'start_time': 8, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_mid_ZN_1'}, {'value': 40, 'start_time': 8, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_mid_ZN_1'}, {'value': 22, 'start_time': 8, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_mid_ZN_2'}, {'value': 40, 'start_time': 8, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_mid_ZN_2'}, {'value': 22, 'start_time': 8, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_mid_ZN_3'}, {'value': 40, 'start_time': 8, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_mid_ZN_3'}, {'value': 22, 'start_time': 8, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_mid_ZN_4'}, {'value': 40, 'start_time': 8, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_mid_ZN_4'}, {'value': 22, 'start_time': 8, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_top_ZN_1'}, {'value': 40, 'start_time': 8, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_top_ZN_1'}, {'value': 22, 'start_time': 8, 'priority': 0, ...
# ------------------------------------------------------------------------------------------------------------
# 9
# {'Core_bottom': 24.589243744606076, 'Core_mid': 26.285157486218594, 'Core_top': 25.415726509545117, 'FirstFloor_Plenum': 24.50243345952538, 'MidFloor_Plenum': 25.1807417894395, 'Perimeter_bot_ZN_1': 24.010533885031723, 'Perimeter_bot_ZN_2': 24.259179028629198, 'Perimeter_bot_ZN_3': 23.99586077986373, 'Perimeter_bot_ZN_4': 23.95435453631753, 'Perimeter_mid_ZN_1': 25.304945712551906, 'Perimeter_mid_ZN_2': 25.52511771963012, 'Perimeter_mid_ZN_3': 25.288391528137186, 'Perimeter_mid_ZN_4': 25.24062317191589, 'Perimeter_top_ZN_1': 24.672201807340194, 'Perimeter_top_ZN_2': 24.88966839896236, 'Perimeter_top_ZN_3': 24.653161917752968, 'Perimeter_top_ZN_4': 24.624443683668108, 'TopFloor_Plenum': 22.27940690244876}
# [{'value': 26, 'start_time': 9, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Core_bottom'}, {'value': 40, 'start_time': 9, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Core_bottom'}, {'value': 26, 'start_time': 9, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Core_mid'}, {'value': 40, 'start_time': 9, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Core_mid'}, {'value': 26, 'start_time': 9, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Core_top'}, {'value': 40, 'start_time': 9, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Core_top'}, {'value': 26, 'start_time': 9, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_bot_ZN_1'}, {'value': 40, 'start_time': 9, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_bot_ZN_1'}, {'value': 26, 'start_time': 9, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_bot_ZN_2'}, {'value': 40, 'start_time': 9, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_bot_ZN_2'}, {'value': 26, 'start_time': 9, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_bot_ZN_3'}, {'value': 40, 'start_time': 9, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_bot_ZN_3'}, {'value': 26, 'start_time': 9, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_bot_ZN_4'}, {'value': 40, 'start_time': 9, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_bot_ZN_4'}, {'value': 26, 'start_time': 9, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_mid_ZN_1'}, {'value': 40, 'start_time': 9, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_mid_ZN_1'}, {'value': 26, 'start_time': 9, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_mid_ZN_2'}, {'value': 40, 'start_time': 9, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_mid_ZN_2'}, {'value': 26, 'start_time': 9, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_mid_ZN_3'}, {'value': 40, 'start_time': 9, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_mid_ZN_3'}, {'value': 26, 'start_time': 9, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_mid_ZN_4'}, {'value': 40, 'start_time': 9, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_mid_ZN_4'}, {'value': 26, 'start_time': 9, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_top_ZN_1'}, {'value': 40, 'start_time': 9, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_top_ZN_1'}, {'value': 26, 'start_time': 9, 'priority': 0, ...
# ------------------------------------------------------------------------------------------------------------
# 10
# {'Core_bottom': 26.007654997810715, 'Core_mid': 26.003397740315076, 'Core_top': 26.00559446918946, 'FirstFloor_Plenum': 25.31594502882748, 'MidFloor_Plenum': 25.692758974614538, 'Perimeter_bot_ZN_1': 26.003079674346914, 'Perimeter_bot_ZN_2': 26.00236677380953, 'Perimeter_bot_ZN_3': 26.003229809728847, 'Perimeter_bot_ZN_4': 26.002449686168042, 'Perimeter_mid_ZN_1': 26.001863836054863, 'Perimeter_mid_ZN_2': 26.001557381445565, 'Perimeter_mid_ZN_3': 26.001927258037806, 'Perimeter_mid_ZN_4': 26.00165237630903, 'Perimeter_top_ZN_1': 26.002264340233186, 'Perimeter_top_ZN_2': 26.001766672800226, 'Perimeter_top_ZN_3': 26.002395936945724, 'Perimeter_top_ZN_4': 26.001791924577223, 'TopFloor_Plenum': 23.82034350715956}
# [{'value': 18, 'start_time': 10, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Core_bottom'}, {'value': 40, 'start_time': 10, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Core_bottom'}, {'value': 18, 'start_time': 10, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Core_mid'}, {'value': 40, 'start_time': 10, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Core_mid'}, {'value': 18, 'start_time': 10, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Core_top'}, {'value': 40, 'start_time': 10, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Core_top'}, {'value': 18, 'start_time': 10, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_bot_ZN_1'}, {'value': 40, 'start_time': 10, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_bot_ZN_1'}, {'value': 18, 'start_time': 10, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_bot_ZN_2'}, {'value': 40, 'start_time': 10, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_bot_ZN_2'}, {'value': 18, 'start_time': 10, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_bot_ZN_3'}, {'value': 40, 'start_time': 10, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_bot_ZN_3'}, {'value': 18, 'start_time': 10, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_bot_ZN_4'}, {'value': 40, 'start_time': 10, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_bot_ZN_4'}, {'value': 18, 'start_time': 10, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_mid_ZN_1'}, {'value': 40, 'start_time': 10, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_mid_ZN_1'}, {'value': 18, 'start_time': 10, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_mid_ZN_2'}, {'value': 40, 'start_time': 10, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_mid_ZN_2'}, {'value': 18, 'start_time': 10, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_mid_ZN_3'}, {'value': 40, 'start_time': 10, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_mid_ZN_3'}, {'value': 18, 'start_time': 10, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_mid_ZN_4'}, {'value': 40, 'start_time': 10, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_mid_ZN_4'}, {'value': 18, 'start_time': 10, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_top_ZN_1'}, {'value': 40, 'start_time': 10, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_top_ZN_1'}, {'value': 18, 'start_ ...
# ------------------------------------------------------------------------------------------------------------
# 11
# {'Core_bottom': 24.976838229079757, 'Core_mid': 26.46868387955965, 'Core_top': 25.69725561926666, 'FirstFloor_Plenum': 24.919148100872142, 'MidFloor_Plenum': 25.281603444841092, 'Perimeter_bot_ZN_1': 25.240455274877316, 'Perimeter_bot_ZN_2': 25.36585136881923, 'Perimeter_bot_ZN_3': 25.14737830488066, 'Perimeter_bot_ZN_4': 25.155744269336726, 'Perimeter_mid_ZN_1': 26.11062527566903, 'Perimeter_mid_ZN_2': 26.2492476841957, 'Perimeter_mid_ZN_3': 26.005777435612444, 'Perimeter_mid_ZN_4': 25.982610726934187, 'Perimeter_top_ZN_1': 25.725484485185945, 'Perimeter_top_ZN_2': 25.82831426371146, 'Perimeter_top_ZN_3': 25.619316120343694, 'Perimeter_top_ZN_4': 25.62974451830983, 'TopFloor_Plenum': 23.06441357001802}
# [{'value': 21, 'start_time': 11, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Core_bottom'}, {'value': 40, 'start_time': 11, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Core_bottom'}, {'value': 21, 'start_time': 11, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Core_mid'}, {'value': 40, 'start_time': 11, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Core_mid'}, {'value': 21, 'start_time': 11, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Core_top'}, {'value': 40, 'start_time': 11, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Core_top'}, {'value': 21, 'start_time': 11, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_bot_ZN_1'}, {'value': 40, 'start_time': 11, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_bot_ZN_1'}, {'value': 21, 'start_time': 11, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_bot_ZN_2'}, {'value': 40, 'start_time': 11, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_bot_ZN_2'}, {'value': 21, 'start_time': 11, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_bot_ZN_3'}, {'value': 40, 'start_time': 11, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_bot_ZN_3'}, {'value': 21, 'start_time': 11, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_bot_ZN_4'}, {'value': 40, 'start_time': 11, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_bot_ZN_4'}, {'value': 21, 'start_time': 11, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_mid_ZN_1'}, {'value': 40, 'start_time': 11, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_mid_ZN_1'}, {'value': 21, 'start_time': 11, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_mid_ZN_2'}, {'value': 40, 'start_time': 11, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_mid_ZN_2'}, {'value': 21, 'start_time': 11, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_mid_ZN_3'}, {'value': 40, 'start_time': 11, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_mid_ZN_3'}, {'value': 21, 'start_time': 11, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_mid_ZN_4'}, {'value': 40, 'start_time': 11, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_mid_ZN_4'}, {'value': 21, 'start_time': 11, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_top_ZN_1'}, {'value': 40, 'start_time': 11, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_top_ZN_1'}, {'value': 21, 'start_ ...
# ------------------------------------------------------------------------------------------------------------
# 12
# {'Core_bottom': 24.99195057918362, 'Core_mid': 26.414945995906287, 'Core_top': 25.87444275291543, 'FirstFloor_Plenum': 24.897573991398108, 'MidFloor_Plenum': 25.526663174374534, 'Perimeter_bot_ZN_1': 25.301935858923805, 'Perimeter_bot_ZN_2': 25.35849582888929, 'Perimeter_bot_ZN_3': 25.166060669843585, 'Perimeter_bot_ZN_4': 25.171759152329674, 'Perimeter_mid_ZN_1': 26.449987544993164, 'Perimeter_mid_ZN_2': 26.485184707073532, 'Perimeter_mid_ZN_3': 26.267361523375737, 'Perimeter_mid_ZN_4': 26.279430137238677, 'Perimeter_top_ZN_1': 25.958333845680116, 'Perimeter_top_ZN_2': 25.99351357771735, 'Perimeter_top_ZN_3': 25.808486334328485, 'Perimeter_top_ZN_4': 25.822813050734286, 'TopFloor_Plenum': 23.63609337648569}
# [{'value': 22, 'start_time': 12, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Core_bottom'}, {'value': 40, 'start_time': 12, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Core_bottom'}, {'value': 22, 'start_time': 12, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Core_mid'}, {'value': 40, 'start_time': 12, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Core_mid'}, {'value': 22, 'start_time': 12, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Core_top'}, {'value': 40, 'start_time': 12, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Core_top'}, {'value': 22, 'start_time': 12, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_bot_ZN_1'}, {'value': 40, 'start_time': 12, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_bot_ZN_1'}, {'value': 22, 'start_time': 12, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_bot_ZN_2'}, {'value': 40, 'start_time': 12, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_bot_ZN_2'}, {'value': 22, 'start_time': 12, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_bot_ZN_3'}, {'value': 40, 'start_time': 12, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_bot_ZN_3'}, {'value': 22, 'start_time': 12, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_bot_ZN_4'}, {'value': 40, 'start_time': 12, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_bot_ZN_4'}, {'value': 22, 'start_time': 12, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_mid_ZN_1'}, {'value': 40, 'start_time': 12, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_mid_ZN_1'}, {'value': 22, 'start_time': 12, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_mid_ZN_2'}, {'value': 40, 'start_time': 12, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_mid_ZN_2'}, {'value': 22, 'start_time': 12, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_mid_ZN_3'}, {'value': 40, 'start_time': 12, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_mid_ZN_3'}, {'value': 22, 'start_time': 12, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_mid_ZN_4'}, {'value': 40, 'start_time': 12, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_mid_ZN_4'}, {'value': 22, 'start_time': 12, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_top_ZN_1'}, {'value': 40, 'start_time': 12, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_top_ZN_1'}, {'value': 22, 'start_ ...
# ------------------------------------------------------------------------------------------------------------
# 13
# {'Core_bottom': 24.900325856774455, 'Core_mid': 26.504595290204406, 'Core_top': 25.96162052510196, 'FirstFloor_Plenum': 24.987862463210888, 'MidFloor_Plenum': 25.592534930475928, 'Perimeter_bot_ZN_1': 25.593971807471572, 'Perimeter_bot_ZN_2': 25.57384193754885, 'Perimeter_bot_ZN_3': 25.41323713007166, 'Perimeter_bot_ZN_4': 25.487591314309114, 'Perimeter_mid_ZN_1': 26.795721227092425, 'Perimeter_mid_ZN_2': 26.7515341264439, 'Perimeter_mid_ZN_3': 26.58280687977797, 'Perimeter_mid_ZN_4': 26.65765522838889, 'Perimeter_top_ZN_1': 26.340710573068563, 'Perimeter_top_ZN_2': 26.29316327191026, 'Perimeter_top_ZN_3': 26.142430327292825, 'Perimeter_top_ZN_4': 26.220630894070194, 'TopFloor_Plenum': 24.060742756002682}
# [{'value': 25, 'start_time': 13, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Core_bottom'}, {'value': 40, 'start_time': 13, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Core_bottom'}, {'value': 25, 'start_time': 13, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Core_mid'}, {'value': 40, 'start_time': 13, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Core_mid'}, {'value': 25, 'start_time': 13, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Core_top'}, {'value': 40, 'start_time': 13, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Core_top'}, {'value': 25, 'start_time': 13, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_bot_ZN_1'}, {'value': 40, 'start_time': 13, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_bot_ZN_1'}, {'value': 25, 'start_time': 13, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_bot_ZN_2'}, {'value': 40, 'start_time': 13, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_bot_ZN_2'}, {'value': 25, 'start_time': 13, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_bot_ZN_3'}, {'value': 40, 'start_time': 13, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_bot_ZN_3'}, {'value': 25, 'start_time': 13, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_bot_ZN_4'}, {'value': 40, 'start_time': 13, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_bot_ZN_4'}, {'value': 25, 'start_time': 13, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_mid_ZN_1'}, {'value': 40, 'start_time': 13, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_mid_ZN_1'}, {'value': 25, 'start_time': 13, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_mid_ZN_2'}, {'value': 40, 'start_time': 13, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_mid_ZN_2'}, {'value': 25, 'start_time': 13, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_mid_ZN_3'}, {'value': 40, 'start_time': 13, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_mid_ZN_3'}, {'value': 25, 'start_time': 13, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_mid_ZN_4'}, {'value': 40, 'start_time': 13, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_mid_ZN_4'}, {'value': 25, 'start_time': 13, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_top_ZN_1'}, {'value': 40, 'start_time': 13, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_top_ZN_1'}, {'value': 25, 'start_ ...
# ------------------------------------------------------------------------------------------------------------
# 14
# {'Core_bottom': 24.93605375452476, 'Core_mid': 26.548663245636874, 'Core_top': 26.126495115971576, 'FirstFloor_Plenum': 25.005780865433685, 'MidFloor_Plenum': 25.656796071142384, 'Perimeter_bot_ZN_1': 25.472190113921858, 'Perimeter_bot_ZN_2': 25.435919206438726, 'Perimeter_bot_ZN_3': 25.28311815553684, 'Perimeter_bot_ZN_4': 25.457234880538948, 'Perimeter_mid_ZN_1': 26.71165164428962, 'Perimeter_mid_ZN_2': 26.652130177924015, 'Perimeter_mid_ZN_3': 26.487138041545858, 'Perimeter_mid_ZN_4': 26.672473708194687, 'Perimeter_top_ZN_1': 26.344414053991382, 'Perimeter_top_ZN_2': 26.264830326415396, 'Perimeter_top_ZN_3': 26.116605280101773, 'Perimeter_top_ZN_4': 26.3007133874877, 'TopFloor_Plenum': 24.30647807184625}
# [{'value': 19, 'start_time': 14, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Core_bottom'}, {'value': 40, 'start_time': 14, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Core_bottom'}, {'value': 19, 'start_time': 14, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Core_mid'}, {'value': 40, 'start_time': 14, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Core_mid'}, {'value': 19, 'start_time': 14, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Core_top'}, {'value': 40, 'start_time': 14, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Core_top'}, {'value': 19, 'start_time': 14, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_bot_ZN_1'}, {'value': 40, 'start_time': 14, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_bot_ZN_1'}, {'value': 19, 'start_time': 14, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_bot_ZN_2'}, {'value': 40, 'start_time': 14, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_bot_ZN_2'}, {'value': 19, 'start_time': 14, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_bot_ZN_3'}, {'value': 40, 'start_time': 14, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_bot_ZN_3'}, {'value': 19, 'start_time': 14, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_bot_ZN_4'}, {'value': 40, 'start_time': 14, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_bot_ZN_4'}, {'value': 19, 'start_time': 14, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_mid_ZN_1'}, {'value': 40, 'start_time': 14, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_mid_ZN_1'}, {'value': 19, 'start_time': 14, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_mid_ZN_2'}, {'value': 40, 'start_time': 14, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_mid_ZN_2'}, {'value': 19, 'start_time': 14, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_mid_ZN_3'}, {'value': 40, 'start_time': 14, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_mid_ZN_3'}, {'value': 19, 'start_time': 14, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_mid_ZN_4'}, {'value': 40, 'start_time': 14, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_mid_ZN_4'}, {'value': 19, 'start_time': 14, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_top_ZN_1'}, {'value': 40, 'start_time': 14, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_top_ZN_1'}, {'value': 19, 'start_ ...
# ------------------------------------------------------------------------------------------------------------
# 15
# {'Core_bottom': 24.944576094617783, 'Core_mid': 26.595596666030392, 'Core_top': 26.256774695457526, 'FirstFloor_Plenum': 25.062825727484938, 'MidFloor_Plenum': 25.720027169063503, 'Perimeter_bot_ZN_1': 25.514753670063342, 'Perimeter_bot_ZN_2': 25.47699000239887, 'Perimeter_bot_ZN_3': 25.326674595073666, 'Perimeter_bot_ZN_4': 25.637848787056075, 'Perimeter_mid_ZN_1': 26.78396124773027, 'Perimeter_mid_ZN_2': 26.71880384892156, 'Perimeter_mid_ZN_3': 26.577027895597787, 'Perimeter_mid_ZN_4': 26.880097696292346, 'Perimeter_top_ZN_1': 26.45394369246975, 'Perimeter_top_ZN_2': 26.37785370262379, 'Perimeter_top_ZN_3': 26.249507717169884, 'Perimeter_top_ZN_4': 26.553558720823077, 'TopFloor_Plenum': 24.662252037494035}
# [{'value': 30, 'start_time': 15, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Core_bottom'}, {'value': 40, 'start_time': 15, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Core_bottom'}, {'value': 30, 'start_time': 15, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Core_mid'}, {'value': 40, 'start_time': 15, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Core_mid'}, {'value': 30, 'start_time': 15, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Core_top'}, {'value': 40, 'start_time': 15, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Core_top'}, {'value': 30, 'start_time': 15, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_bot_ZN_1'}, {'value': 40, 'start_time': 15, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_bot_ZN_1'}, {'value': 30, 'start_time': 15, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_bot_ZN_2'}, {'value': 40, 'start_time': 15, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_bot_ZN_2'}, {'value': 30, 'start_time': 15, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_bot_ZN_3'}, {'value': 40, 'start_time': 15, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_bot_ZN_3'}, {'value': 30, 'start_time': 15, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_bot_ZN_4'}, {'value': 40, 'start_time': 15, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_bot_ZN_4'}, {'value': 30, 'start_time': 15, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_mid_ZN_1'}, {'value': 40, 'start_time': 15, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_mid_ZN_1'}, {'value': 30, 'start_time': 15, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_mid_ZN_2'}, {'value': 40, 'start_time': 15, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_mid_ZN_2'}, {'value': 30, 'start_time': 15, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_mid_ZN_3'}, {'value': 40, 'start_time': 15, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_mid_ZN_3'}, {'value': 30, 'start_time': 15, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_mid_ZN_4'}, {'value': 40, 'start_time': 15, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_mid_ZN_4'}, {'value': 30, 'start_time': 15, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_top_ZN_1'}, {'value': 40, 'start_time': 15, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_top_ZN_1'}, {'value': 30, 'start_ ...
# ...
# [{'value': 29, 'start_time': 326, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Core_bottom'}, {'value': 40, 'start_time': 326, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Core_bottom'}, {'value': 29, 'start_time': 326, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Core_mid'}, {'value': 40, 'start_time': 326, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Core_mid'}, {'value': 29, 'start_time': 326, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Core_top'}, {'value': 40, 'start_time': 326, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Core_top'}, {'value': 29, 'start_time': 326, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_bot_ZN_1'}, {'value': 40, 'start_time': 326, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_bot_ZN_1'}, {'value': 29, 'start_time': 326, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_bot_ZN_2'}, {'value': 40, 'start_time': 326, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_bot_ZN_2'}, {'value': 29, 'start_time': 326, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_bot_ZN_3'}, {'value': 40, 'start_time': 326, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_bot_ZN_3'}, {'value': 29, 'start_time': 326, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_bot_ZN_4'}, {'value': 40, 'start_time': 326, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_bot_ZN_4'}, {'value': 29, 'start_time': 326, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_mid_ZN_1'}, {'value': 40, 'start_time': 326, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_mid_ZN_1'}, {'value': 29, 'start_time': 326, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_mid_ZN_2'}, {'value': 40, 'start_time': 326, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_mid_ZN_2'}, {'value': 29, 'start_time': 326, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_mid_ZN_3'}, {'value': 40, 'start_time': 326, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_mid_ZN_3'}, {'value': 29, 'start_time': 326, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_mid_ZN_4'}, {'value': 40, 'start_time': 326, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_mid_ZN_4'}, {'value': 29, 'start_time': 326, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_top_ZN_1'}, {'value': 40, 'start_time': 326, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_top_ZN_1' ...
# ------------------------------------------------------------------------------------------------------------
# 327
# {'Core_bottom': 29.000231758681295, 'Core_mid': 28.998877062244645, 'Core_top': 28.997745021368285, 'FirstFloor_Plenum': 28.070285617251226, 'MidFloor_Plenum': 28.567923448776614, 'Perimeter_bot_ZN_1': 28.999792941134622, 'Perimeter_bot_ZN_2': 28.994062137650772, 'Perimeter_bot_ZN_3': 29.001010750281498, 'Perimeter_bot_ZN_4': 28.99258905534501, 'Perimeter_mid_ZN_1': 28.99688429621691, 'Perimeter_mid_ZN_2': 28.982095360768078, 'Perimeter_mid_ZN_3': 28.99587368186854, 'Perimeter_mid_ZN_4': 28.984653840867697, 'Perimeter_top_ZN_1': 28.996273078244062, 'Perimeter_top_ZN_2': 28.985273128937976, 'Perimeter_top_ZN_3': 28.99480189358177, 'Perimeter_top_ZN_4': 28.98256491500924, 'TopFloor_Plenum': 29.196827327145915}
# [{'value': 30, 'start_time': 327, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Core_bottom'}, {'value': 40, 'start_time': 327, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Core_bottom'}, {'value': 30, 'start_time': 327, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Core_mid'}, {'value': 40, 'start_time': 327, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Core_mid'}, {'value': 30, 'start_time': 327, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Core_top'}, {'value': 40, 'start_time': 327, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Core_top'}, {'value': 30, 'start_time': 327, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_bot_ZN_1'}, {'value': 40, 'start_time': 327, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_bot_ZN_1'}, {'value': 30, 'start_time': 327, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_bot_ZN_2'}, {'value': 40, 'start_time': 327, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_bot_ZN_2'}, {'value': 30, 'start_time': 327, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_bot_ZN_3'}, {'value': 40, 'start_time': 327, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_bot_ZN_3'}, {'value': 30, 'start_time': 327, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_bot_ZN_4'}, {'value': 40, 'start_time': 327, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_bot_ZN_4'}, {'value': 30, 'start_time': 327, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_mid_ZN_1'}, {'value': 40, 'start_time': 327, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_mid_ZN_1'}, {'value': 30, 'start_time': 327, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_mid_ZN_2'}, {'value': 40, 'start_time': 327, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_mid_ZN_2'}, {'value': 30, 'start_time': 327, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_mid_ZN_3'}, {'value': 40, 'start_time': 327, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_mid_ZN_3'}, {'value': 30, 'start_time': 327, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_mid_ZN_4'}, {'value': 40, 'start_time': 327, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_mid_ZN_4'}, {'value': 30, 'start_time': 327, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Heating Setpoint', 'actuator_key': 'Perimeter_top_ZN_1'}, {'value': 40, 'start_time': 327, 'priority': 0, 'component_type': 'Zone Temperature Control', 'control_type': 'Cooling Setpoint', 'actuator_key': 'Perimeter_top_ZN_1' ...
# ------------------------------------------------------------------------------------------------------------
# 328
# {'Core_bottom': 29.646103286051975, 'Core_mid': 30.000031453252436, 'Core_top': 29.999171885204852, 'FirstFloor_Plenum': 28.37070427898897, 'MidFloor_Plenum': 28.942935537019455, 'Perimeter_bot_ZN_1': 30.000730163849454, 'Perimeter_bot_ZN_2': 29.995954663254707, 'Perimeter_bot_ZN_3': 30.001799981667833, 'Perimeter_bot_ZN_4': 29.989154743603585, 'Perimeter_mid_ZN_1': 29.995919349353223, 'Perimeter_mid_ZN_2': 29.984071788082552, 'Perimeter_mid_ZN_3': 29.998526472244656, 'Perimeter_mid_ZN_4': 29.988045123383788, 'Perimeter_top_ZN_1': 29.99326592977793, 'Perimeter_top_ZN_2': 29.979554614082787, 'Perimeter_top_ZN_3': 29.99680680463131, 'Perimeter_top_ZN_4': 29.98678987507997, 'TopFloor_Plenum': 29.99484734656347}
# []
# ------------------------------------------------------------------------------------------------------------
# 329
# {'Core_bottom': 29.87819922409721, 'Core_mid': 30.001830740770963, 'Core_top': 30.00149619532997, 'FirstFloor_Plenum': 28.3672191051909, 'MidFloor_Plenum': 28.91389621627753, 'Perimeter_bot_ZN_1': 30.00257092042399, 'Perimeter_bot_ZN_2': 30.001320120915874, 'Perimeter_bot_ZN_3': 30.00296758689709, 'Perimeter_bot_ZN_4': 29.998477538174807, 'Perimeter_mid_ZN_1': 30.00103156001998, 'Perimeter_mid_ZN_2': 29.99779341620674, 'Perimeter_mid_ZN_3': 30.001597704289004, 'Perimeter_mid_ZN_4': 29.997702904923734, 'Perimeter_top_ZN_1': 30.000322365897613, 'Perimeter_top_ZN_2': 29.996320496521736, 'Perimeter_top_ZN_3': 30.00116321223354, 'Perimeter_top_ZN_4': 29.9972833710849, 'TopFloor_Plenum': 30.03545207341398}
# []
# ------------------------------------------------------------------------------------------------------------
# 330
# {'Core_bottom': 29.945457126458113, 'Core_mid': 30.000454588721826, 'Core_top': 30.00037217494158, 'FirstFloor_Plenum': 28.471973498568456, 'MidFloor_Plenum': 28.952429494086164, 'Perimeter_bot_ZN_1': 30.001979466775122, 'Perimeter_bot_ZN_2': 30.00169009584206, 'Perimeter_bot_ZN_3': 30.00217021592364, 'Perimeter_bot_ZN_4': 30.00076675623449, 'Perimeter_mid_ZN_1': 30.001298834976286, 'Perimeter_mid_ZN_2': 30.00126314507394, 'Perimeter_mid_ZN_3': 30.00136222397082, 'Perimeter_mid_ZN_4': 30.000403810812294, 'Perimeter_top_ZN_1': 30.00117469492124, 'Perimeter_top_ZN_2': 30.001193073199598, 'Perimeter_top_ZN_3': 30.00121245119308, 'Perimeter_top_ZN_4': 30.00031237378799, 'TopFloor_Plenum': 29.392718781480973}
# []
# ------------------------------------------------------------------------------------------------------------
# 331
# {'Core_bottom': 27.749734977357804, 'Core_mid': 29.11795916263621, 'Core_top': 29.558140780336277, 'FirstFloor_Plenum': 27.681834639878822, 'MidFloor_Plenum': 28.296903239533318, 'Perimeter_bot_ZN_1': 27.63230471518657, 'Perimeter_bot_ZN_2': 27.595263003865874, 'Perimeter_bot_ZN_3': 27.699160682388122, 'Perimeter_bot_ZN_4': 29.77064537219176, 'Perimeter_mid_ZN_1': 28.636293144028976, 'Perimeter_mid_ZN_2': 28.53911665643962, 'Perimeter_mid_ZN_3': 28.69479436938927, 'Perimeter_mid_ZN_4': 30.825292118856694, 'Perimeter_top_ZN_1': 28.84073778996718, 'Perimeter_top_ZN_2': 28.767578075362028, 'Perimeter_top_ZN_3': 28.912267595609705, 'Perimeter_top_ZN_4': 31.06115686198829, 'TopFloor_Plenum': 29.047409785239072}
# []
# ------------------------------------------------------------------------------------------------------------
# 332
# {'Core_bottom': 30.001132925324214, 'Core_mid': 30.000760101263634, 'Core_top': 30.000637783554556, 'FirstFloor_Plenum': 28.56530488876851, 'MidFloor_Plenum': 29.059158006097586, 'Perimeter_bot_ZN_1': 30.003257005561288, 'Perimeter_bot_ZN_2': 30.00239502574722, 'Perimeter_bot_ZN_3': 30.003526952111255, 'Perimeter_bot_ZN_4': 30.001829420366214, 'Perimeter_mid_ZN_1': 30.002052116517707, 'Perimeter_mid_ZN_2': 30.00166786276551, 'Perimeter_mid_ZN_3': 30.002180085284063, 'Perimeter_mid_ZN_4': 30.00120382804883, 'Perimeter_top_ZN_1': 30.001795971097604, 'Perimeter_top_ZN_2': 30.001516822334487, 'Perimeter_top_ZN_3': 30.001883026971402, 'Perimeter_top_ZN_4': 30.001099750228363, 'TopFloor_Plenum': 29.130177252348552}
# []
# ------------------------------------------------------------------------------------------------------------
# 333
# {'Core_bottom': 27.74833357028107, 'Core_mid': 29.126137949925553, 'Core_top': 29.50078966788409, 'FirstFloor_Plenum': 27.700810640117652, 'MidFloor_Plenum': 28.31590852003685, 'Perimeter_bot_ZN_1': 27.31116092839234, 'Perimeter_bot_ZN_2': 27.28605420516137, 'Perimeter_bot_ZN_3': 27.304350635176007, 'Perimeter_bot_ZN_4': 27.689411985068254, 'Perimeter_mid_ZN_1': 28.338819491162997, 'Perimeter_mid_ZN_2': 28.274954047647295, 'Perimeter_mid_ZN_3': 28.323307438693135, 'Perimeter_mid_ZN_4': 28.732606344345314, 'Perimeter_top_ZN_1': 28.550767586206018, 'Perimeter_top_ZN_2': 28.494922834593567, 'Perimeter_top_ZN_3': 28.534848976289755, 'Perimeter_top_ZN_4': 28.78132278162955, 'TopFloor_Plenum': 28.01721383498782}
# []
# ------------------------------------------------------------------------------------------------------------
# 334
# {'Core_bottom': 29.999697290185626, 'Core_mid': 29.999826007993054, 'Core_top': 29.99984541396063, 'FirstFloor_Plenum': 28.628544311018093, 'MidFloor_Plenum': 29.11271138326613, 'Perimeter_bot_ZN_1': 30.002400011588982, 'Perimeter_bot_ZN_2': 30.001957091489444, 'Perimeter_bot_ZN_3': 30.002612677655264, 'Perimeter_bot_ZN_4': 30.00178188332332, 'Perimeter_mid_ZN_1': 30.00157027593159, 'Perimeter_mid_ZN_2': 30.001444608941377, 'Perimeter_mid_ZN_3': 30.001645930906065, 'Perimeter_mid_ZN_4': 30.00127447259507, 'Perimeter_top_ZN_1': 30.00143527072351, 'Perimeter_top_ZN_2': 30.001361176700282, 'Perimeter_top_ZN_3': 30.00149643948508, 'Perimeter_top_ZN_4': 30.00116779728328, 'TopFloor_Plenum': 28.483716966850377}
# []
# Writing tabular output file results using HTML format.
# Writing final SQL reports
# EnergyPlus Run Time=00hr 00min  2.62sec
# ------------------------------------------------------------------------------------------------------------
# 335
# {'Core_bottom': 27.78089315126278, 'Core_mid': 29.19108825366829, 'Core_top': 29.4119211278396, 'FirstFloor_Plenum': 27.756371708578442, 'MidFloor_Plenum': 28.370419024517375, 'Perimeter_bot_ZN_1': 27.32485620730057, 'Perimeter_bot_ZN_2': 27.306036571014705, 'Perimeter_bot_ZN_3': 27.307178799151124, 'Perimeter_bot_ZN_4': 27.563317753523638, 'Perimeter_mid_ZN_1': 28.381757165784272, 'Perimeter_mid_ZN_2': 28.327701646660117, 'Perimeter_mid_ZN_3': 28.362028964467296, 'Perimeter_mid_ZN_4': 28.656263640648685, 'Perimeter_top_ZN_1': 28.506069170739814, 'Perimeter_top_ZN_2': 28.458651538662213, 'Perimeter_top_ZN_3': 28.48632849109507, 'Perimeter_top_ZN_4': 28.75698729802605, 'TopFloor_Plenum': 27.093518942047137}
# []

# %%
{
    'actuator': 
         {'Zone Temperature Control|*|Heating Setpoint|*|SPACE1-1': [0, 26, None], 
          'Zone Temperature Control|*|Cooling Setpoint|*|SPACE1-1': [0, 40, None], 
          'Zone Temperature Control|*|Heating Setpoint|*|SPACE2-1': [0, 26, None], 
          'Zone Temperature Control|*|Cooling Setpoint|*|SPACE2-1': [0, 40, None], 
          'Zone Temperature Control|*|Heating Setpoint|*|SPACE3-1': [0, 26, None], 
          'Zone Temperature Control|*|Cooling Setpoint|*|SPACE3-1': [0, 40, None], 
          'Zone Temperature Control|*|Heating Setpoint|*|SPACE4-1': [0, 26, None], 
          'Zone Temperature Control|*|Cooling Setpoint|*|SPACE4-1': [0, 40, None], 
          'Zone Temperature Control|*|Heating Setpoint|*|SPACE5-1': [0, 26, None], 
          'Zone Temperature Control|*|Cooling Setpoint|*|SPACE5-1': [0, 40, None]}, 
    'global': {}
}
# Out:
# '{"actuator": {"Zone Temperature Control|*|Heating Setpoint|*|SPACE1-1": [0, 26, null], "Zone Temperature Control|*|Cooling Setpoint|*|SPACE1-1": [0, 40, null], "Zone Temperature Control|*|Heating Setpoint|*|SPACE2-1": [0, 26, null], "Zone Temperature Control|*|Cooling Setpoint|*|SPACE2-1": [0, 40, null], "Zone Temperature Control|*|Heating Setpoint|*|SPACE3-1": [0, 26, null], "Zone Temperature Control|*|Cooling Setpoint|*|SPACE3-1": [0, 40, null], "Zone Temperature Control|*|Heating Setpoint|*|SPACE4-1": [0, 26, null], "Zone Temperature Control|*|Cooling Setpoint|*|SPACE4-1": [0, 40, null], "Zone Temperature Control|*|Heating Setpoint|*|SPACE5-1": [0, 26, null], "Zone Temperature Control|*|Cooling Setpoint|*|SPACE5-1": [0, 40, null]}, "global": {}}'

# %% [markdown]
# <a id="example"></a>
# ## Example of Building Joint Control using COBS
#
# We present another GitHub repository from our previous work [**On the Joint Control of Multiple Building Systems with Reinforcement Learning**](https://github.com/sustainable-computing/COBS-joint-control). This paper explores rule-based and RL-based control of building subsystems (HVAC, lighting, shading) in a 5-zone office building in Pittsburgh, Pennsylvania in January (heating season) and July (cooling season). The floor area of this building is 5,000 square feet. The control setpoints that we adjust using different algorithms to maximize energy savings, thermal comfort, and visual comfort are supply air temperature setpoint and blind angle setpoint. [This IDF file](https://github.com/sustainable-computing/COBS-joint-control/blob/master/eplus_files/5Zone_Control_SAT_no_windowcontrol.idf) describes the simulated building. COBS is used in this work to programmatically execute rule-based control scenarios and to train the RL agents. The office building we control is depicted in the figure below.
# ![building-layout](https://github.com/sustainable-computing/COBS-joint-control/raw/master/building_schematic.png)
#
# [Back to top](#table-of-contents)
